# %% [markdown]
# # Purpose:

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
import numpy.matlib

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()
import tensorflow_probability as tfp
from tensorflow.python.keras.optimizer_v2.adam import Adam
tfd = tfp.distributions
import tensorflow.keras.backend as K
from tensorflow import math as tfm

import os

import utilsProb
import utilsProbSS
import glob
import sys
from scipy.stats import rankdata
import pandas as pd
import importlib
import copy
from netCDF4 import Dataset, num2date
from scipy.interpolate import interpn
from matplotlib.colors import Normalize 
from matplotlib import cm
import matplotlib as mpl
import seaborn as sns
sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
import properscoring as ps
from math import erf
import xarray as xr

import matplotlib
#mapping
from cartopy import config
import cartopy.crs as ccrs
import cartopy.feature as cf
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import Unet_b
import utils_CNN
from tensorflow.python.client import device_lib
import xarray as xr
# Out:
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %% [markdown]
# # Do CUDA Handling

# %%
def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())

os.environ["CUDA_VISIBLE_DEVICES"]="0"

if tf.test.gpu_device_name() != '/device:GPU:0':
    print('WARNING: GPU device not found.')
else:
    print('SUCCESS: Found GPU: {}'.format(tf.test.gpu_device_name()))
# Out:
# ['/device:GPU:0']
# SUCCESS: Found GPU: /device:GPU:0

# %%
print('We are here:',os.getcwd())
os.chdir('/glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/')
#reloading utils after changes:
importlib.reload(utilsProbSS)
importlib.reload(utilsProb)
importlib.reload(utils_CNN)
importlib.reload(Unet_b)
# Out:
# We are here: /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal
# <module 'Unet_b' from '/glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/Unet_b.py'>

# %%
negloglik = lambda y, rv_y: -rv_y.log_prob(y)


def cdf_of_normal(true,ypred,scale):
    return 0.5*(1+erf((true-ypred)/(scale*np.sqrt(2))))

def rmse(guess,truth):
    n = len(truth)
    rms = np.linalg.norm(guess - truth) / np.sqrt(n)
    return rms


def bias(guess,truth):
    bb = np.mean(guess)-np.mean(truth)
    return bb

def corrss(guess,truth):
    bb = np.corrcoef(np.squeeze(guess),np.squeeze(truth))[0,1]
    return bb


def crmse(guess,truth):
    guess = np.squeeze(guess)
    truth = np.squeeze(truth)
    mg = np.mean(guess)
    mt = np.mean(truth)
    n = len(truth)
    bb=np.linalg.norm((guess-mg) - (truth-mt)) / np.sqrt(n)
    return bb

def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]


def spreadskill(guess,truth,stddevver,numbins):
#     guess: postprocess guess any input shape
#     truth: true value any input shape 
#     stddevver: standard deviation of the guess any input shape
#     returns: 
#         variance mean, mse mean, bootstraped variance, bootrapped mean
    
    distPP = np.ndarray.flatten(stddevver)
    guess = np.ndarray.flatten(guess)
    truth = np.ndarray.flatten(truth)
    
    indexsort = np.argsort(distPP)
    err = (guess- truth)**2
    varianceall = distPP[indexsort]
    err_sort = err[indexsort]

    numbins = numbins 
    inds = np.zeros(len(varianceall))
    numst = 0
    for nn in range(numbins):
        numdo = int(len(varianceall)/numbins)
        inds[numst:numdo*(nn+1)] = nn
    
        if nn ==np.max(range(numbins)):
            inds[numst:] = nn
        numst+=numdo
    
    avgvar_m = []
    msebin_m = []

    avgvar_s = []
    msebin_s = []
    nummy =2000

    for bb in np.unique(inds):
        locbin = np.where([inds==bb])[1]
        tavg =0
        tmse =0
        tavg = np.zeros(nummy)
        tmse = np.zeros(nummy)
        for ii in range(nummy):
            tavg[ii]  = np.mean(np.random.choice(varianceall[locbin],len(locbin)))
            tmse[ii]  = np.sqrt(np.mean(np.random.choice(err_sort[locbin],len(locbin))))
        avgvar_m = np.append(avgvar_m,np.mean(tavg))
        msebin_m = np.append(msebin_m,np.mean(tmse))
        avgvar_s = np.append(avgvar_s,np.std(tavg))
        msebin_s = np.append(msebin_s,np.std(tmse))
    return avgvar_m,msebin_m,avgvar_s,msebin_s

def density_scatter( x , y, ax = None, sort = True, bins = 20, **kwargs )   :
    """
    Scatter plot colored by 2d histogram
    """
    if ax is None :
        fig , ax = plt.subplots(figsize=(10, 8))
    data , x_e, y_e = np.histogram2d( x, y, bins = bins, density = True )
    z = interpn( ( 0.5*(x_e[1:] + x_e[:-1]) , 0.5*(y_e[1:]+y_e[:-1]) ) , data , np.vstack([x,y]).T , method = "splinef2d", bounds_error = False)

    #To be sure to plot all data
    z[np.where(np.isnan(z))] = 0.0

    # Sort the points by density, so that the densest points are plotted last
    if sort :
        idx = z.argsort()
        x, y, z = x[idx], y[idx], z[idx]

    ax.scatter( x, y, c=z, **kwargs )

    norm = Normalize(vmin = np.min(z), vmax = np.max(z))
    cbar = fig.colorbar(cm.ScalarMappable(norm = norm), ax=ax)
    cbar.ax.set_ylabel('Density')

    return ax


def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))
    return tf.keras.Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype,name='banjo'),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1),name='banjo2'),
  ])


# Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
def prior_trainable(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    return tf.keras.Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype,name='spoon'),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1),name='doon'),
  ])



def stnd_error_mean(guess,truth,numbins):
#     guess: postprocess guess any input shape
#     truth: true value any input shape 
#     stddevver: standard deviation of the guess any input shape
#     returns: 
#         variance mean, mse mean, bootstraped variance, bootrapped mean
    
    guess = np.ndarray.flatten(guess)
    truth = np.ndarray.flatten(truth)
    

    err = (guess- truth)**2
    indexsort = np.argsort(err)
    err_sort = err[indexsort]
    
    truthSORT = truth[indexsort]
    guessSORT = guess[indexsort]

    numbins = numbins 
    inds = np.zeros(len(err_sort))
    numst = 0
    for nn in range(numbins):
        numdo = int(len(err_sort)/numbins)
        inds[numst:numdo*(nn+1)] = nn
    
        if nn ==np.max(range(numbins)):
            inds[numst:] = nn
        numst+=numdo
        
    msebin_m = []
    msebin_s = []
    nummy =2000
    maxlist=[]
    for bb in np.unique(inds):
        locbin = np.where([inds==bb])[1]
        tmse =0
        tmse = np.zeros(nummy)
        for ii in range(nummy):
            tmse[ii]  = np.sqrt(np.mean(np.random.choice(err_sort[locbin],len(locbin))))
        msebin_m = np.append(msebin_m,np.mean(tmse))
        msebin_s = np.append(msebin_s,np.std(tmse))
        
        if bb == np.max(np.unique(inds)):
            print('...getting max...')
            mlt = truthSORT[locbin]
            mlg = guessSORT[locbin]
            mle = np.sqrt((truthSORT[locbin]-guessSORT[locbin])**2)
            
        
    return msebin_m,msebin_s,mlt,mlg,mle


def crps_cost_function_LogNorm(y_true, y_pred, theano=False):
    """Compute the CRPS cost function for a lognormal distribution defined by
    the mean and standard deviation.
    Big Ups to Stephan Rasp & Sebastian Lerch. 
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred[:, 0]
    sigma = y_pred[:, 1]
    y = y_true
    # Ugly workaround for different tensor allocation in keras and theano
    if not theano:
        y= y_true[:, 0]   # Need to also get rid of axis 1 to match!

    # To stop sigma from becoming negative we first have to 
    # convert it the the variance and then take the square
    # root again. 
    sigma = K.abs(sigma)
    var = K.square(sigma)
    # The following three variables are just for convenience
    loc = (y_true - mu) / sigma
    
    c1 = y * (2* 0.5 + 0.5*(tfm.erf((tfm.log(y)-mu)/(np.sqrt(2)*sigma))))
    
    c2 = 2*K.exp(mu+0.5*K.square(sigma))
    
    c3 = 0.5 + 0.5*(tfm.erf((tfm.log(y)-(mu+sigma**2))/(np.sqrt(2)*sigma)))
    
    c4 = (0.5*(1+tfm.erf((sigma/np.sqrt(2))/np.sqrt(2))))-1
    
    # First we will compute the crps for each input/target pair
    crps = c1-c2*(c3+c4)
        
    # Then we take the mean. The cost is now a scalar
    diff = y-(K.exp(mu+((K.square(sigma))/2)))
    greater = K.greater(diff,0)
    greater = K.cast(greater, K.floatx())*1 #0 for lower, 1 for greater
#     greater = greater + 1                 #1 for lower, 5 for greater

    return K.mean(crps) #+ K.mean(greater*diff)

def crps_logis_cost_function(y_true, y_pred, theano=False):
    """Compute the CRPS cost function for a logistic distribution defined by
    the mean and standard deviation.
    Big Ups to Stephan Rasp & Sebastian Lerch. 
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred[:, 0]
    sigma = y_pred[:, 1]
    y = y_true
    # Ugly workaround for different tensor allocation in keras and theano
    if not theano:
        y= y_true[:, 0]   # Need to also get rid of axis 1 to match!

    # To stop sigma from becoming negative we first have to 
    # convert it the the variance and then take the square
    # root again. 
    sigma = K.abs(sigma)
    var = K.square(sigma)
    # The following three variables are just for convenience
    loc = (y_true - mu) / sigma
    
    
    # First we will compute the crps for each input/target pair
    crps =  K.sqrt(var) * (loc-2*K.log(1/(1+K.exp(-loc)))-1)
    # Then we take the mean. The cost is now a scalar
    return K.mean(crps)


def crps_cost_function(y_true, y_pred, theano=False):
    """Compute the CRPS cost function for a normal distribution defined by
    the mean and standard deviation.
    Code inspired by Kai Polsterer (HITS).
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred[:,:,:,0]
    sigma = K.abs(y_pred[:,:,:,1])
    # Ugly workaround for different tensor allocation in keras and theano
    if not theano:
        y_true = y_true[:,:,:,0]   # Need to also get rid of axis 1 to match!

    # To stop sigma from becoming negative we first have to 
    # convert it the the variance and then take the square
    # root again. 
    var = K.square(sigma)
    # The following three variables are just for convenience
    loc = (y_true - mu) / sigma
    phi = 1.0 / np.sqrt(2.0 * np.pi) * K.exp(-K.square(loc) / 2.0)
    Phi = 0.5 * (1.0 + tfm.erf(loc / np.sqrt(2.0)))
    # First we will compute the crps for each input/target pair
    crps =  sigma * (loc * (2. * Phi - 1.) + 2 * phi - 1. / np.sqrt(np.pi))
    # Then we take the mean. The cost is now a scalar
    return K.mean(crps)


#MAKE SURE YOUR true values are NEVER zero when using this. 


def crps_Lnorm_TEST(y_true, y_pred, sig_pred):
    """Compute the CRPS cost function for a normal distribution defined by
    the mean and standard deviation.
    Code inspired by Kai Polsterer (HITS).
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """
    # Split input
    mu = y_pred
    sigma = sig_pred
    y = y_true
    c1 = y * (2*plnorm(y,mu,sigma)-1)
    c2 = 2*np.exp(mu+0.5*sigma**2)
    c3 = plnorm(y,mu+sigma**2,sigma) 
    c4 = pnorm(sigma/np.sqrt(2))-1
    crps = c1-c2*(c3+c4)
    return np.mean(crps)


def crps_logis_TEST(y_true, y_pred, sig_pred):
    """Compute the CRPS cost function for a normal distribution defined by
    the mean and standard deviation.
    Code inspired by Kai Polsterer (HITS).
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred
    sigma = sig_pred
    var = sigma**2
    
    # The following three variables are just for convenience
    loc = (y_true - mu) / np.sqrt(var)
    # First we will compute the crps for each input/target pair
    crps =  np.sqrt(var) * (loc-2*np.log(1/(1+np.exp(-loc)))-1)
    # Then we take the mean. The cost is now a scalar
    return np.mean(crps)


def crps_TEST(y_true, y_pred, sig_pred):
    """Compute the CRPS cost function for a normal distribution defined by
    the mean and standard deviation.
    Code inspired by Kai Polsterer (HITS).
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred
    sigma = sig_pred

    # To stop sigma from becoming negative we first have to 
    # convert it the the variance and then take the square
    # root again. 
    var = sigma**2
    # The following three variables are just for convenience
    loc = (y_true - mu) / np.sqrt(var)
    phi = 1.0 / np.sqrt(2.0 * np.pi) * np.exp(-(loc**2) / 2.0)
    Phi = 0.5 * (1.0 + math.erf(loc / np.sqrt(2.0)))
    # First we will compute the crps for each input/target pair
    crps =  np.sqrt(var) * (loc * (2. * Phi - 1.) + 2 * phi - 1. / np.sqrt(np.pi))
    # Then we take the mean. The cost is now a scalar
    return np.mean(crps)

def plnorm(y,mu,sigma):
    nummy=0.5 + 0.5*(math.erf((np.log(y)-mu)/(np.sqrt(2)*sigma)))
    return nummy 

def pnorm(loc):
    nummy=0.5*(1+math.erf(loc/np.sqrt(2)))
    return nummy 



def build_emb_model(n_features, n_outputs, hidden_nodes, emb_size, max_id,
                    compile=False, optimizer='adam', lr=0.0001,
                    loss=crps_cost_function,
                    activation='relu', reg=None):
    """
    Args:
        n_features: Number of features
        n_outputs: Number of outputs
        hidden_nodes: int or list of hidden nodes
        emb_size: Embedding size
        max_id: Max embedding ID
        compile: If true, compile model
        optimizer: Name of optimizer
        lr: learning rate
        loss: loss function
        activation: Activation function for hidden layer
    Returns:
        model: Keras model
    """
    if type(hidden_nodes) is not list:
        hidden_nodes = [hidden_nodes]

    features_in = tf.keras.layers.Input(shape=(n_features,))
    id_in = tf.keras.layers.Input(shape=(1,))
    emb = tf.keras.layers.Embedding(max_id + 1, emb_size)(id_in)
    emb = tf.keras.layers.Flatten()(emb)
    x = tf.keras.layers.Concatenate()([features_in, emb])
    for h in hidden_nodes:
        x = tf.keras.layers.Dense(h, activation=activation, kernel_regularizer=reg)(x)
    x = tf.keras.layers.Dense(n_outputs, activation='linear', kernel_regularizer=reg)(x)
    model = tf.keras.models.Model(inputs=[features_in, id_in], outputs=x)

    if compile:
        opt = tf.optimizers.Adam(learning_rate=lr)
        model.compile(optimizer=opt, loss=loss)
    return model

def lognstat(mu, sigma):
    """Calculate the mean of and variance of the lognormal distribution given
    the mean (`mu`) and standard deviation (`sigma`), of the associated normal 
    distribution."""
    m = np.exp(mu + sigma**2 / 2.0)
    v = np.exp(2 * mu + sigma**2) * (np.exp(sigma**2) - 1)
    return m, v


def ranker(obs_array,Ensemble):
    """Compute the rank histogram rankings
    obs_array = np.array[time,];           e.g. obs_array.shape = (136884,)
    Ensemble = np.array([Ensemble,time]);  e.g. Ensemble.shape  = (15, 136884)
     """
    combined=np.vstack((np.array(obs_array)[np.newaxis],Ensemble))
    print('computing ranks')
    ranks=np.apply_along_axis(lambda x: rankdata(x,method='min'),0,combined)

    print('computing ties')
    ties=np.sum(ranks[0]==ranks[1:], axis=0)
    ranks=ranks[0]
    
    return ranks

# %% [markdown]
# ## Check Region of Interest

# %%
latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/'
lat = np.arange(22,60.5,.5)
lon = np.arange(200.0,249.375+.625,.625)
MapPoints = np.zeros([lat.shape[0],lon.shape[0]])
print('...Searching...:',latlonfolder)
path = latlonfolder
pp_file_names = [f for f in glob.glob(path + "/lat*lon*", recursive=True)]
pp_file_names = sorted(pp_file_names)

for ff in pp_file_names:
    #find the appropriate lat/lon index
    ff2 = ff.split('lat')[1]
    ff3 = (ff2.split('lon'))
    latfind = float(ff3[0])
    lonfind = float(ff3[1])
    indlat= np.where(lat==latfind)[0][0]
    indlon= np.where(lon==lonfind)[0][0]
    MapPoints[indlat,indlon] = np.random.uniform()
    
MapPoints[MapPoints==0]=np.nan
print("number of points:", len(pp_file_names))

##################### plotting ###############################

fig = plt.figure(figsize=(18, 9), dpi= 80, facecolor='w', edgecolor='k')
cmap1 = matplotlib.cm.get_cmap("Blues",lut=55)

proj = ccrs.PlateCarree()

ax = plt.subplot(1, 1, 1,projection = proj)
ax.add_feature(cf.BORDERS)

ax.set_xticks(np.linspace(-180,-150, 11), crs=proj)
ax.set_yticks(np.linspace(20, 60, 7), crs=proj)
ax.add_feature(cf.NaturalEarthFeature(
               category='cultural',
               name='admin_1_states_provinces_lines',
               scale='50m',
               facecolor='none'))

ax.coastlines()
ax.add_feature(cf.BORDERS)
ax.set_extent([-160, -105, 29.5, 55])
scales = 1
ff = plt.pcolor(np.squeeze(lon),np.squeeze(lat),MapPoints,cmap=cmap1,vmin=0,vmax=scales)
plt.title('map of points',fontsize=20)

# savepath = dd + '/Map_of_points.pdf'
# plt.savefig(savepath , dpi=80)
plt.show()
# plt.close('all')
# Out:
# ...Searching...: /glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/
# number of points: 144

# %% [markdown]
# ## What time step to look at:

# %%
stepnum=9

dd = '/glade/scratch/wchapman/Reforecast/'
os.chdir(dd)

yago= next(os.walk('.'))[1]
yago = sorted(yago)
subs = 'F'
res = [ii for ii in yago if subs in ii] 
res
for fcast in res[:stepnum]: 
    os.chdir(dd+'/'+fcast)
    print(os.getcwd())
# Out:
# /glade/scratch/wchapman/Reforecast/F000
# /glade/scratch/wchapman/Reforecast/F006
# /glade/scratch/wchapman/Reforecast/F012
# /glade/scratch/wchapman/Reforecast/F018
# /glade/scratch/wchapman/Reforecast/F024
# /glade/scratch/wchapman/Reforecast/F030
# /glade/scratch/wchapman/Reforecast/F036
# /glade/scratch/wchapman/Reforecast/F042
# /glade/scratch/wchapman/Reforecast/F048

# %%
batch_num = 50
epochs = 30
#find all files in directory                                                                                                                                                  
print('Training on')
path = os.getcwd()
train_file_names = sorted([f for f in glob.glob(path + "/train/*_500mb.nc", recursive=True)])
for f in train_file_names:
    print(f)

print('Validating on')
validate_file_names = sorted([f for f in glob.glob(path + "/validate/*_500mb.nc", recursive=True)])
for f in validate_file_names:
    print(f)
    
print('Testing on')
test_file_names = sorted([f for f in glob.glob(path + "/test/*_500mb.nc", recursive=True)])
for f in test_file_names:
    print(f)
    
All_file_names =train_file_names + validate_file_names +test_file_names
# Out:
# Training on
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc
# /glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc
# Validating on
# /glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc
# Testing on
# /glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc

# %% [markdown]
# # Grab only the years you want:

# %%
yearstoinclude = ['1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005',
                  '2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']
res=[]
for jj in yearstoinclude:
    res.append([i for i in All_file_names if jj in i][0])
    
print(res)
# Out:
# ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']

# %%
norm_dict = utils_CNN.get_image_normalization_params(res)
sys.stdout.flush()
norm_dict_targ = utils_CNN.get_image_normalization_params_targ(res)

# sys.stdout.flush()
# num_samps_train = utilsProb.count_samps(train_file_names)
# num_samps_val = utilsProb.count_samps(validate_file_names)
# num_samps_test = utilsProb.count_samps(test_file_names)

# print('number of training samples:',num_samps_train)
# # sys.stdout.flush()

# print('number of validation samples:',num_samps_val)
# # sys.stdout.flush()
# print('number of validation samples:',num_samps_test)
# num_samps_tot = num_samps_train+num_samps_val+num_samps_test
# Out:
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
#
#
# Mean and standard deviation for "IVT" = 157.9026, 150.6681
# Mean and standard deviation for "p_sfc" = 983.9274, 62.0042
# Mean and standard deviation for "u_tr_p" = 12.6646, 12.2930
# Mean and standard deviation for "v_tr_p" = 1.4922, 13.3376
# Mean and standard deviation for "Z_p" = 5567.2482, 201.4786
# Mean and standard deviation for "IWV" = 13.1403, 7.5054
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
#
#
# Mean and standard deviation for "IVTm" = 202.7490, 182.3662

# %% [markdown]
# ## Only for this one
# We do not normalize the target dictionary

# %%
norm_dict_targ['IVTm'][0]=0
norm_dict_targ['IVTm'][1]=1

# %% [markdown]
# # Big Loop
# Run this off this notebook in CrossVal.py

# %%
All_file_names

allinds = np.arange(len(res))

for bb in range(len(res)-3,len(res)):
    
    if bb == (len(res)-1):
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[-3]]]
        val_fil_name = [res[allinds[-1]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    else:
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[bb+1]]]
        val_fil_name = [res[allinds[bb]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utils_CNN.deep_learning_generator(train_fil_name, num_samps_train,norm_dict,norm_dict_targ)
    adf = next(aa)
    x = adf[0]
    y = adf[1]

    aa = utils_CNN.deep_learning_generator(val_fil_name, num_samps_val,norm_dict,norm_dict_targ)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]
    
    
#     ### Model Build #### 
    img_height = x.shape[1]
    img_width = x.shape[2]
    num_channels = x.shape[3]
    img_shape = (img_height, img_width, num_channels)
    nummy_classes = 2

    model = Unet_b.model_simple_unet_initializer(img_shape=img_shape, cost_func=crps_cost_function,num_classes=nummy_classes,num_levels = 1,num_layers =2, num_bottleneck = 3, filter_size_start =16, batch_norm=None, kernel_size = 3, 
                                     bottleneck_dilation = True, bottleneck_sum_activation =False)

#     in_shape = x.shape[1]
#     print('In shape: ',in_shape)
#     out_shape = 1
#     print('Out shape: ',out_shape)    
    
#     max_id = np.max(stID)
    
#     model = build_emb_model(in_shape,2,[30,40],2,max_id,compile=True)
    
#     model.summary()
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
#     #save location:
    newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/CNN_'+tstyr
    if not os.path.exists(newdir):
        os.makedirs(newdir)
    
    Wsave_name = newdir+'/cpf_CRPS_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
    print(Wsave_name)
    print(Wsave_name)

    modsave = tf.keras.callbacks.ModelCheckpoint(Wsave_name, monitor='val_loss', verbose=1, save_best_only=True,save_weights_only=True, mode='min',include_optimizer=False)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.4,patience=2, min_lr=0.00001,verbose=1)
    er_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto',baseline=None, restore_best_weights=False)
    
    #train model
    histss = model.fit(x, y,validation_data=(x_tst,y_tst), epochs=40,batch_size=50 ,verbose=True,callbacks=[modsave,reduce_lr,er_stop]);
    hist_df = pd.DataFrame(histss.history) 
   
    # or save to csv: 
    hist_csv_file = newdir+'/fithist_CRPS_'+ valyr+'_test_'+tstyr+'.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
# Out:
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 72, 60, 6)    0           input_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# Train on 3816 samples, validate on 119 samples
# Epoch 1/40
# 3700/3816 [============================>.] - ETA: 0s - loss: 77.8781
# Epoch 00001: val_loss improved from inf to 56.08472, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# 3816/3816 [==============================] - 10s 3ms/sample - loss: 76.5989 - val_loss: 56.0847
# Epoch 2/40
# 3650/3816 [===========================>..] - ETA: 0s - loss: 31.7723
# Epoch 00002: val_loss improved from 56.08472 to 42.16322, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# 3816/3816 [==============================] - 1s 294us/sample - loss: 31.7650 - val_loss: 42.1632
# Epoch 3/40
# 3650/3816 [===========================>..] - ETA: 0s - loss: 30.6218
# Epoch 00003: val_loss improved from 42.16322 to 31.22306, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# 3816/3816 [==============================] - 1s 291us/sample - loss: 30.5585 - val_loss: 31.2231
# Epoch 4/40
# 3650/3816 [===========================>..] - ETA: 0s - loss: 29.7580
# Epoch 00004: val_loss did not improve from 31.22306
# 3816/3816 [==============================] - 1s 284us/sample - loss: 29.7672 - val_loss: 33.0686
# Epoch 5/40
# 2450/3816 [==================>...........] - ETA: 0s - loss: 29.6325WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %% [markdown]
# ## Big Loop
# validation data evaluation

# %%
All_file_names
allinds = np.arange(len(res))

ense = 21
numbins = 15
allinds = np.arange(len(All_file_names))


avgvar_mA = np.zeros([len(All_file_names),numbins])
msebin_mA = np.zeros([len(All_file_names),numbins])
avgvar_sA = np.zeros([len(All_file_names),numbins])
msebin_sA = np.zeros([len(All_file_names),numbins])

mAl =np.array([])
sAl =np.array([])
yAl =np.array([])
wwrfAl = np.array([])
latoutAl = np.array([])
lonoutAl = np.array([])
tout = np.array([],dtype='datetime64[ns]')

print('######### ASSEMBLE!!!! ###########')
#find lat/lons of interest:
rang = 144
latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/'
[latsDO,lonsDO,latind, lonind] = utilsProbSS.get_latlon_ind(latlonfolder)
latsDO.shape
latind = np.array(latind[:rang])
lonind = np.array(lonind[:rang])
latsDO = np.array(latsDO[:rang])
lonsDO = np.array(lonsDO[:rang])
print('########### DONE!!!! #############')



for ddfa, bb in enumerate(range(len(res)-3,len(res))):
    
    if bb == (len(res)-1):
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[-3]]]
        val_fil_name = [res[allinds[-1]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    else:
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[bb+1]]]
        val_fil_name = [res[allinds[bb]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utils_CNN.deep_learning_generator(train_fil_name, num_samps_train,norm_dict,norm_dict_targ)
    adf = next(aa)
    x = adf[0]
    y = adf[1]

    aa = utils_CNN.deep_learning_generator_nordnm(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]
    
    
#     ### Model Build #### 
    img_height = x.shape[1]
    img_width = x.shape[2]
    num_channels = x.shape[3]
    img_shape = (img_height, img_width, num_channels)
    nummy_classes = 2

    model = Unet_b.model_simple_unet_initializer(img_shape=img_shape, cost_func=crps_cost_function,num_classes=nummy_classes,num_levels = 1,num_layers =2, num_bottleneck = 3, filter_size_start =16, batch_norm=None, kernel_size = 3, 
                                     bottleneck_dilation = True, bottleneck_sum_activation =False)

    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
#     #save location:
    newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/CNN_'+tstyr
    if not os.path.exists(newdir):
        os.makedirs(newdir)
    
    Wsave_name = newdir+'/cpf_CRPS_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
    print('########### model name:',Wsave_name)
    print('########### model name:',Wsave_name)
    
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    model.load_weights(Wsave_name)
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    
    yhat = model(x_tst)
    yhat = yhat.numpy()
    
    m = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    m2 = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    mm = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    s = np.abs(np.ndarray.flatten(yhat[:,latind,lonind,1],order='F'))
    
    WWRF = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
    WWRF = np.ndarray.flatten(WWRF[:,latind,lonind],order='F')
    
    y_tst = (utilsProbSS.denormalize_images_targ(np.ndarray.flatten(y_tst[:,latind,lonind,0],order='F'),'IVTm',norm_dict_targ))
    y_tst=np.expand_dims(y_tst,axis=1)
    
    #gather other variables of interest (time and lat/lon)
    op = xr.open_dataset(test_fil_name[0])
    lat = op['lat'][:].data
    lon = op['lon'][:].data
    lat_out = np.ndarray.flatten(np.matlib.repmat(lat[latind],x_tst.shape[0],1),order='F')
    lon_out = np.ndarray.flatten(np.matlib.repmat(lon[lonind],x_tst.shape[0],1),order='F')
    time_out = np.ndarray.flatten(np.matlib.repmat(op['time'][:].data,latind.shape[0],1)) 
    

    #form ensembles 
    m_All = np.zeros(len(m))
    sss_All = np.zeros([len(m),ense])
    s_All = np.zeros(len(m))
    
    
    for ii in range(len(m)):
        sss = np.random.normal(m[ii],s[ii],ense)
        sln=np.std(sss)
        mln=np.mean(sss)
        [mln,sln]=lognstat(m[ii],s[ii])
        s_All[ii]=s[ii]
        m_All[ii]=m[ii]
        sss_All[ii,:] =(sss) 

    m = m_All
    m[np.isnan(m)]=0
    s=s_All
    s[np.isnan(m)]=0
    
    y_tst = (y_tst)
    WWRF = (WWRF)
    distPP = s
    
    if ddfa == 0:
        sssAl = sss_All
    else: 
        sssAl = np.concatenate([sssAl,sss_All],axis=0)
    
    
    
    
    if bb == (len(res)-1):
        mAl = np.append(np.ndarray.flatten(m),mAl)
        yAl = np.append(np.ndarray.flatten(y_tst),yAl)
        sAl = np.append(np.ndarray.flatten(s),sAl)
        wwrfAl = np.append(np.ndarray.flatten(WWRF),wwrfAl)
        latoutAl = np.append(np.ndarray.flatten(lat_out),latoutAl)
        lonoutAl = np.append(np.ndarray.flatten(lon_out),lonoutAl)
        tout = np.append(np.ndarray.flatten(time_out),tout)
    else:
        mAl = np.append(mAl,np.ndarray.flatten(m))
        yAl = np.append(yAl,np.ndarray.flatten(y_tst))
        sAl = np.append(sAl,np.ndarray.flatten(s))
        wwrfAl = np.append(wwrfAl,np.ndarray.flatten(WWRF))
        latoutAl = np.append(latoutAl,np.ndarray.flatten(lat_out))
        lonoutAl = np.append(lonoutAl,np.ndarray.flatten(lon_out))
        tout = np.append(tout,np.ndarray.flatten(time_out))
    
    print('...binned spread skill...')
    [avgvar_m,msebin_m,avgvar_s,msebin_s]=spreadskill(m,y_tst,distPP,numbins)
    
    avgvar_mA[bb,:] = np.squeeze(avgvar_m)
    msebin_mA[bb,:] = np.squeeze(msebin_m)
    avgvar_sA[bb,:] = np.squeeze(avgvar_s)
    msebin_sA[bb,:] = np.squeeze(msebin_s)
    
    plt.figure(figsize=[15,10])  # inches
    plt.errorbar(avgvar_m, (msebin_m), xerr=avgvar_s, yerr=msebin_s, uplims=True, lolims=True,color='r',linewidth=2)
    plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
    plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

    plt.tick_params(axis='x', labelsize=15)
    plt.tick_params(axis='y', labelsize=15)
    plt.title('Spread Skill Plot',fontsize=25)

    plt.plot([0,140],[0,140],'k--')
    plt.show()
    
    print(rmse(np.expand_dims(m,axis=1),y_tst))
    print(rmse(np.expand_dims(WWRF,axis=1),y_tst))
    print(crmse(np.expand_dims(m,axis=1),y_tst))
    print(crmse(np.expand_dims(WWRF,axis=1),y_tst))
    print(bias(np.expand_dims(m,axis=1),y_tst))
    print(bias(np.expand_dims(WWRF,axis=1),y_tst))
    
newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/Reforecast_out/'
print('IVTm shape:', yAl.shape)
print('IVT mean shape:', mAl.shape)
print('IVT std shape:', sAl.shape)

df_out = pd.DataFrame({'time':tout,'OBS':yAl,'Model':wwrfAl,'IVTmean':mAl,'IVTstd':sAl,'lat':latoutAl,'lon':lonoutAl})
# df_out.to_pickle(newdir+'NN_CRPS_CNNPP_ref2.pkl')
# np.savez(newdir+'NN_CRPS_CNNPP_ref2.npz',lat=lat,lon=lon,IVTgefsm=mAl,IVTgefss=sAl,IVTm_gefs=yAl)
# Out:
# ######### ASSEMBLE!!!! ###########
# ########### DONE!!!! #############
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 72, 60, 6)    0           input_17[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_16[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_16 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# ...binned spread skill...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 56.683180797807445
# 47.8084413890903
# 49.29976220488765
# 47.509044735597186
# -27.973486924719637
# 5.3420715
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Model: "model_17"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_18 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 72, 60, 6)    0           input_18[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_17[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_17[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_17 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2018/cpf_CRPS_val_2017_test_2018.ckpt
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2018/cpf_CRPS_val_2017_test_2018.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# ...binned spread skill...
# 45.81600427693663
# 52.847079004870515
# 45.79152736672039
# 52.659770526164586
# -1.4974230208428025
# 4.4455414
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 72, 60, 6)    0           input_19[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_18[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_18[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_18 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2016/cpf_CRPS_val_2018_test_2016.ckpt
# ########### model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2016/cpf_CRPS_val_2018_test_2016.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# ...binned spread skill...
# 55.313392408536465
# 60.98833967909431
# 55.14271569352985
# 60.980383470215074
# -4.341933253098603
# 0.9853058
# IVTm shape: (51408,)
# IVT mean shape: (51408,)
# IVT std shape: (51408,)

# %% [markdown]
# ## Get date file ... save as pkl.

# %%
aa = utils_CNN.deep_learning_generator(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
adf = next(aa)
x_tst = adf[0]
y_tst = adf[1]
WWRF = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
# Out:
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...

# %%
#####
aa = utils_CNN.deep_learning_generator_nordnm(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
adf = next(aa)
x_tst = adf[0]
y_tst = adf[1]
WWRF = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)

IVTwwrf = np.ndarray.flatten(WWRF[:,latind,lonind],order='F')
IVTmerra = np.ndarray.flatten(y_tst[:,latind,lonind,0],order='F')

op = xr.open_dataset(test_fil_name[0])
IVTxr = op['IVT'][:].data
lat = op['lat'][:].data
lon = op['lon'][:].data
lat_out = np.ndarray.flatten(np.matlib.repmat(lat[latind],x_tst.shape[0],1),order='F')
lon_out = np.ndarray.flatten(np.matlib.repmat(lon[lonind],x_tst.shape[0],1),order='F')
time_out = np.ndarray.flatten(np.matlib.repmat(op['time'][:].data,latind.shape[0],1)) 

####
# CHECK ALL OF THIS PLEASE!!!!
# Out:
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...

# %% [markdown]
# ## Test Cases

# %%
WWRF = utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)
pp = np.argwhere(y_tst>350)


nummms = pp[74][0]
guess=np.random.normal(m[nummms],s[nummms],1000)
plt.figure(figsize=[15,10])  
sns.distplot(guess,40,color='k')
plt.axvline(WWRF[nummms],color='r',linewidth=4)
plt.axvline(y_tst[nummms],color='k',linewidth=4)
plt.axvline((m[nummms]),color='k',linestyle=':',linewidth=4)
plt.xlim([0,1000])
plt.show()

# %% [markdown]
# ## Rank Histogram

# %%
Thresher = 250 #thresh to stratify on. 
rr2 = ranker(yAl[mAl>Thresher],np.transpose(sssAl[mAl>Thresher]))

print('making figure... takes FOREVER')
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
# plt.hist(rr,density=True,bins=30,alpha=0.4,label='AnEn')
plt.hist(rr2,density=True,bins=22,alpha=0.4,label='CRPS',color='k')
plt.plot([-10,80],[0.047,0.047],'k--')
plt.legend(fontsize=26)
plt.ylim([0,0.2])
plt.xlim([0,23])
# plt.savefig('/glade/scratch/wchapman/Reforecast/models/RankHist_'+fcast+'_ThreshOBS250_ForecastHour.png',dpi = 300,bbox_inches='tight')
plt.show()
# Out:
# computing ranks
# computing ties
# making figure... takes FOREVER

# %% [markdown]
# ## PIT Diagram

# %%
_set = []
_transformed_set = []
 
num_ense=200
for ii in range(yAl.shape[0]):
    texpp = cdf_of_normal(yAl[ii],mAl[ii],sAl[ii])
    _transformed_set.append(texpp)
   
print('...making figure...')
plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
plt.hist(_transformed_set,density=True,bins=16,alpha=0.4,label='CNN_CRPS',color='k')
plt.plot([-10,80],[1,1],'k--')
plt.legend(fontsize=26)
plt.ylim([0,4])
plt.xlim([0,1])
plt.xticks(fontsize=19)
plt.yticks(fontsize=19)

plt.show()
# Out:
# ...making figure...

# %%
import properscoring as ps
distPPT = (np.squeeze(sAl))
print('...binned spread skill...')
[avgvar_mT,msebin_mT,avgvar_sT,msebin_sT]=spreadskill(mAl,yAl,distPPT,numbins)
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/Spread_Skill_CRPS.npz',mAl=mAl,yAl=yAl,distPPT=distPPT,
#                     numbins=numbins,avgvar_mA=avgvar_mA,msebin_mA=msebin_mA,avgvar_sA=avgvar_sA,msebin_sA=msebin_sA)

crps_ense = ps.crps_ensemble(np.squeeze(yAl[yAl>250]),sssAl[np.squeeze([yAl>250][0][:]),:])
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/twCRPS_CRPS.npz',yAl=yAl,sssAl=sssAl,crps_ense=crps_ense)


plt.figure(figsize=[15,10])  # inches
mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()


evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]

# Plotting what I actually want
Z=np.arange(1987,2017,1).tolist()
count=0
for ad,bd,cd,dd,ed in zip(avgvar_mA,msebin_mA,avgvar_sA,msebin_sA,Z):
    # setting rgb color based on z normalized to my range
    plt.errorbar(ad, bd, xerr=3*cd, yerr=3*dd, uplims=True, lolims=True,linewidth=2,color=colors[count],alpha=0.4)
    
    count+=1


    
plt.errorbar(avgvar_mT, msebin_mT, xerr=3*avgvar_sT, yerr=3*msebin_sT, uplims=True, lolims=True,linewidth=4,color='k',alpha=1,label='Full Dataset')
plt.legend(fontsize=20)
plt.plot([0,180],[0,180],linestyle='--',linewidth=3,color=[0.5,0.5,0.5])

plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('Boost Spread Skill Plot',fontsize=25)
cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
cb.ax.tick_params(labelsize=20) 
plt.xlim([0,200])
plt.ylim([0,200])

plt.show()
# Out:
# ...binned spread skill...

# %% [markdown]
# # Fine Tune it

# %%
yearstoinclude = ['2016','2017','2018']
res=[]
for jj in yearstoinclude:
    res.append([i for i in All_file_names if jj in i][0])
    
print(res)
# Out:
# ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc', '/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']

# %%
All_file_names

allinds = np.arange(len(res))

for bb in range(len(res)-3,len(res)):
    
    if bb == (len(res)-1):
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[-3]]]
        val_fil_name = [res[allinds[-1]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    else:
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[bb+1]]]
        val_fil_name = [res[allinds[bb]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utils_CNN.deep_learning_generator(train_fil_name, num_samps_train,norm_dict,norm_dict_targ)
    adf = next(aa)
    x = adf[0]
    y = adf[1]

    aa = utils_CNN.deep_learning_generator(val_fil_name, num_samps_val,norm_dict,norm_dict_targ)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]

    
#     ### Model Build #### 
    img_height = x.shape[1]
    img_width = x.shape[2]
    num_channels = x.shape[3]
    img_shape = (img_height, img_width, num_channels)
    nummy_classes = 2

    model = Unet_b.model_simple_unet_initializer(img_shape=img_shape, cost_func=crps_cost_function,num_classes=nummy_classes,num_levels = 1,num_layers =2, num_bottleneck = 3, filter_size_start =16, batch_norm=None, kernel_size = 3, 
                                     bottleneck_dilation = True, bottleneck_sum_activation =False)


    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
#     #save location:
    newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/CNN_'+tstyr
    if not os.path.exists(newdir):
        os.makedirs(newdir)
    
    Wsave_name = newdir+'/cpf_CRPS_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
    print('########### Loading old model weights name:',Wsave_name)
    print('########### Loading old model weights name:',Wsave_name)
    print('########### Loading old model weights name:',Wsave_name)
    print('########### Loading old model weights name:',Wsave_name)
    print('########### Loading old model weights name:',Wsave_name)

    print('########### layers frozen ###########')
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    model.load_weights(Wsave_name)
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    for layer in model.layers[:]:
        layer.trainable = False

    # Check the trainable status of the individual layers

    for layer in model.layers:
        print(layer, layer.trainable)


    newout  = tf.keras.layers.Conv2D(32, 3, activation='relu',padding='same')(model.layers[-1].output)
    newout  = tf.keras.layers.Conv2D(2, 3, activation='linear',padding='same')(newout)
    model = tf.keras.models.Model(inputs = model.inputs, outputs = newout)
    opt = optimizer=tf.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer='adam', loss=crps_cost_function)
    model.summary()

    for layer in model.layers:
        print(layer, layer.trainable)
        
    
    Wsave_name = newdir+'/cpf_CRPS_FINETUNE_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
    print('########### Saving new model name:',Wsave_name)

    modsave = tf.keras.callbacks.ModelCheckpoint(Wsave_name, monitor='val_loss', verbose=1, save_best_only=True,save_weights_only=True, mode='min',include_optimizer=False)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.4,patience=2, min_lr=0.00001,verbose=1)
    er_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto',baseline=None, restore_best_weights=False)
    
    #train model
    histss = model.fit(x, y,validation_data=(x_tst,y_tst), epochs=200,batch_size=20 ,verbose=True,callbacks=[modsave,reduce_lr,er_stop]);
    hist_df = pd.DataFrame(histss.history) 
   
    # or save to csv: 
    hist_csv_file = newdir+'/fithist_CRPS_FINETUNE_'+ valyr+'_test_'+tstyr+'.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
# Out:
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F024/validate/F024_WY_2017_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F024/train/F024_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/test/F024_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/train/F024_WY_2016_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/test/F024_WY_2018_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/train/F024_WY_2016_500mb.nc"...
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 72, 60, 6)    0           input_14[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_13[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_13 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_val_2016_test_2017.ckpt
# ########### layers frozen ###########
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x2b10d7cc48d0> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x2b10d7cffb38> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b10d7cffeb8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x2b10d7cffe10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086d78048> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d40898> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x2b1086d5bcf8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086d5bcc0> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x2b1086d642b0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d470b8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d47be0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b10d7cd7390> False
# <tensorflow.python.keras.layers.merge.Add object at 0x2b1086d70f60> False
# <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x2b1086d70eb8> False
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x2b1086ea9198> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086ea9da0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086eb2eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086eb2f98> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086ebd828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086e964a8> False
# <tensorflow.python.keras.layers.convolutional.Cropping2D object at 0x2b1086e967f0> False
# Model: "model_17"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 72, 60, 6)    0           input_14[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_13[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_13 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 71, 57, 32)   608         cropping2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 71, 57, 2)    578         conv2d_6[0][0]
# ==================================================================================================
# Total params: 36,692
# Trainable params: 1,186
# Non-trainable params: 35,506
# __________________________________________________________________________________________________
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x2b10d7cc48d0> False
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x2b10d7cffb38> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b10d7cffeb8> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x2b10d7cffe10> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086d78048> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d40898> False
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x2b1086d5bcf8> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086d5bcc0> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x2b1086d642b0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d470b8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086d47be0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b10d7cd7390> False
# <tensorflow.python.keras.layers.merge.Add object at 0x2b1086d70f60> False
# <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x2b1086d70eb8> False
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x2b1086ea9198> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086ea9da0> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086eb2eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086eb2f98> False
# <tensorflow.python.keras.layers.core.Activation object at 0x2b1086ebd828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086e964a8> False
# <tensorflow.python.keras.layers.convolutional.Cropping2D object at 0x2b1086e967f0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b10d7e1c828> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x2b1086ed5da0> True
# ########### Saving new model name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Train on 120 samples, validate on 120 samples
# Epoch 1/200
#  20/120 [====>.........................] - ETA: 3s - loss: 109.7296
# Epoch 00001: val_loss improved from inf to 54.26722, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 1s 7ms/sample - loss: 80.2688 - val_loss: 54.2672
# Epoch 2/200
#  20/120 [====>.........................] - ETA: 0s - loss: 51.7366
# Epoch 00002: val_loss improved from 54.26722 to 35.71914, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 553us/sample - loss: 42.7126 - val_loss: 35.7191
# Epoch 3/200
#  20/120 [====>.........................] - ETA: 0s - loss: 33.4032
# Epoch 00003: val_loss improved from 35.71914 to 31.14005, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 552us/sample - loss: 31.7299 - val_loss: 31.1400
# Epoch 4/200
#  20/120 [====>.........................] - ETA: 0s - loss: 30.0810
# Epoch 00004: val_loss improved from 31.14005 to 25.99192, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 577us/sample - loss: 28.5118 - val_loss: 25.9919
# Epoch 5/200
#  20/120 [====>.........................] - ETA: 0s - loss: 24.9750
# Epoch 00005: val_loss improved from 25.99192 to 21.31908, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 565us/sample - loss: 22.7837 - val_loss: 21.3191
# Epoch 6/200
#  20/120 [====>.........................] - ETA: 0s - loss: 21.7271
# Epoch 00006: val_loss did not improve from 21.31908
# 120/120 [==============================] - 0s 417us/sample - loss: 22.1549 - val_loss: 22.1203
# Epoch 7/200
#  20/120 [====>.........................] - ETA: 0s - loss: 22.6126
# Epoch 00007: val_loss improved from 21.31908 to 21.07637, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 558us/sample - loss: 21.4000 - val_loss: 21.0764
# Epoch 8/200
#  20/120 [====>.........................] - ETA: 0s - loss: 21.1563
# Epoch 00008: val_loss improved from 21.07637 to 20.92598, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 559us/sample - loss: 21.0155 - val_loss: 20.9260
# Epoch 9/200
#  20/120 [====>.........................] - ETA: 0s - loss: 20.5843
# Epoch 00009: val_loss improved from 20.92598 to 20.06500, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 580us/sample - loss: 20.3999 - val_loss: 20.0650
# Epoch 10/200
#  20/120 [====>.........................] - ETA: 0s - loss: 21.8076
# Epoch 00010: val_loss improved from 20.06500 to 19.70834, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 564us/sample - loss: 19.8942 - val_loss: 19.7083
# Epoch 11/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.2288
# Epoch 00011: val_loss improved from 19.70834 to 19.34297, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 560us/sample - loss: 19.4370 - val_loss: 19.3430
# Epoch 12/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.2259
# Epoch 00012: val_loss improved from 19.34297 to 19.03192, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 559us/sample - loss: 19.0707 - val_loss: 19.0319
# Epoch 13/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.2923
# Epoch 00013: val_loss improved from 19.03192 to 18.75377, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 588us/sample - loss: 18.7523 - val_loss: 18.7538
# Epoch 14/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.6356
# Epoch 00014: val_loss improved from 18.75377 to 18.55219, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 584us/sample - loss: 18.4824 - val_loss: 18.5522
# Epoch 15/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.5154
# Epoch 00015: val_loss improved from 18.55219 to 18.35937, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 570us/sample - loss: 18.2707 - val_loss: 18.3594
# Epoch 16/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.6197
# Epoch 00016: val_loss improved from 18.35937 to 18.25168, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 582us/sample - loss: 18.0918 - val_loss: 18.2517
# Epoch 17/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.2277
# Epoch 00017: val_loss improved from 18.25168 to 18.07529, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 587us/sample - loss: 17.9401 - val_loss: 18.0753
# Epoch 18/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.3247
# Epoch 00018: val_loss improved from 18.07529 to 18.02910, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 594us/sample - loss: 17.8138 - val_loss: 18.0291
# Epoch 19/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.4046
# Epoch 00019: val_loss improved from 18.02910 to 17.89120, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 582us/sample - loss: 17.7135 - val_loss: 17.8912
# Epoch 20/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7190
# Epoch 00020: val_loss improved from 17.89120 to 17.86584, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 580us/sample - loss: 17.6452 - val_loss: 17.8658
# Epoch 21/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.8720
# Epoch 00021: val_loss improved from 17.86584 to 17.77058, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 585us/sample - loss: 17.6090 - val_loss: 17.7706
# Epoch 22/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.4528
# Epoch 00022: val_loss improved from 17.77058 to 17.72319, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 582us/sample - loss: 17.5357 - val_loss: 17.7232
# Epoch 23/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.8461
# Epoch 00023: val_loss improved from 17.72319 to 17.68393, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 585us/sample - loss: 17.4812 - val_loss: 17.6839
# Epoch 24/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.6896
# Epoch 00024: val_loss improved from 17.68393 to 17.62337, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 585us/sample - loss: 17.4215 - val_loss: 17.6234
# Epoch 25/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.9755
# Epoch 00025: val_loss improved from 17.62337 to 17.61307, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 598us/sample - loss: 17.3835 - val_loss: 17.6131
# Epoch 26/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.2975
# Epoch 00026: val_loss did not improve from 17.61307
# 120/120 [==============================] - 0s 415us/sample - loss: 17.3759 - val_loss: 17.6419
# Epoch 27/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.4935
# Epoch 00027: val_loss improved from 17.61307 to 17.52675, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 584us/sample - loss: 17.3636 - val_loss: 17.5267
# Epoch 28/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.6706
# Epoch 00028: val_loss improved from 17.52675 to 17.50769, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 581us/sample - loss: 17.3051 - val_loss: 17.5077
# Epoch 29/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.7423
# Epoch 00029: val_loss did not improve from 17.50769
# 120/120 [==============================] - 0s 414us/sample - loss: 17.2709 - val_loss: 17.5263
# Epoch 30/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.9629
# Epoch 00030: val_loss improved from 17.50769 to 17.48651, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 582us/sample - loss: 17.2575 - val_loss: 17.4865
# Epoch 31/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.5758
# Epoch 00031: val_loss improved from 17.48651 to 17.41562, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 579us/sample - loss: 17.2399 - val_loss: 17.4156
# Epoch 32/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.5217
# Epoch 00032: val_loss improved from 17.41562 to 17.38963, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 591us/sample - loss: 17.1712 - val_loss: 17.3896
# Epoch 33/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.9450
# Epoch 00033: val_loss improved from 17.38963 to 17.35678, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 601us/sample - loss: 17.1409 - val_loss: 17.3568
# Epoch 34/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.7418
# Epoch 00034: val_loss did not improve from 17.35678
# 120/120 [==============================] - 0s 413us/sample - loss: 17.1158 - val_loss: 17.3611
# Epoch 35/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.0431
# Epoch 00035: val_loss improved from 17.35678 to 17.32288, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 613us/sample - loss: 17.1049 - val_loss: 17.3229
# Epoch 36/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.5716
# Epoch 00036: val_loss improved from 17.32288 to 17.27623, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 585us/sample - loss: 17.0957 - val_loss: 17.2762
# Epoch 37/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.2579
# Epoch 00037: val_loss did not improve from 17.27623
# 120/120 [==============================] - 0s 423us/sample - loss: 17.0438 - val_loss: 17.3458
# Epoch 38/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.4992
# Epoch 00038: val_loss improved from 17.27623 to 17.24699, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 589us/sample - loss: 17.0318 - val_loss: 17.2470
# Epoch 39/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.4079
# Epoch 00039: val_loss improved from 17.24699 to 17.23116, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 586us/sample - loss: 17.0017 - val_loss: 17.2312
# Epoch 40/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8291
# Epoch 00040: val_loss improved from 17.23116 to 17.18656, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 591us/sample - loss: 16.9648 - val_loss: 17.1866
# Epoch 41/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.8992
# Epoch 00041: val_loss improved from 17.18656 to 17.15316, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 590us/sample - loss: 16.9615 - val_loss: 17.1532
# Epoch 42/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8569
# Epoch 00042: val_loss did not improve from 17.15316
# 120/120 [==============================] - 0s 419us/sample - loss: 16.9225 - val_loss: 17.1769
# Epoch 43/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.0273
# Epoch 00043: val_loss improved from 17.15316 to 17.12773, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 584us/sample - loss: 16.9087 - val_loss: 17.1277
# Epoch 44/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7227
# Epoch 00044: val_loss improved from 17.12773 to 17.09557, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 594us/sample - loss: 16.8849 - val_loss: 17.0956
# Epoch 45/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8525
# Epoch 00045: val_loss did not improve from 17.09557
# 120/120 [==============================] - 0s 417us/sample - loss: 16.8610 - val_loss: 17.1270
# Epoch 46/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.4520
# Epoch 00046: val_loss improved from 17.09557 to 17.06397, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 580us/sample - loss: 16.8464 - val_loss: 17.0640
# Epoch 47/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.9289
# Epoch 00047: val_loss did not improve from 17.06397
# 120/120 [==============================] - 0s 423us/sample - loss: 16.8459 - val_loss: 17.0904
# Epoch 48/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7082
# Epoch 00048: val_loss improved from 17.06397 to 17.04643, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 562us/sample - loss: 16.8244 - val_loss: 17.0464
# Epoch 49/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7425
# Epoch 00049: val_loss improved from 17.04643 to 17.01425, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 583us/sample - loss: 16.8056 - val_loss: 17.0142
# Epoch 50/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.2044
# Epoch 00050: val_loss did not improve from 17.01425
# 120/120 [==============================] - 0s 420us/sample - loss: 16.7883 - val_loss: 17.0238
# Epoch 51/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.3109
# Epoch 00051: val_loss improved from 17.01425 to 17.01027, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 2ms/sample - loss: 16.7797 - val_loss: 17.0103
# Epoch 52/200
#  20/120 [====>.........................] - ETA: 0s - loss: 14.5770
# Epoch 00052: val_loss improved from 17.01027 to 16.97796, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 568us/sample - loss: 16.7605 - val_loss: 16.9780
# Epoch 53/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.9591
# Epoch 00053: val_loss did not improve from 16.97796
# 120/120 [==============================] - 0s 424us/sample - loss: 16.7476 - val_loss: 16.9853
# Epoch 54/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8360
# Epoch 00054: val_loss improved from 16.97796 to 16.97146, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 578us/sample - loss: 16.7415 - val_loss: 16.9715
# Epoch 55/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.8852
# Epoch 00055: val_loss improved from 16.97146 to 16.95965, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 585us/sample - loss: 16.7252 - val_loss: 16.9596
# Epoch 56/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.0700
# Epoch 00056: val_loss improved from 16.95965 to 16.94825, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 578us/sample - loss: 16.7110 - val_loss: 16.9482
# Epoch 57/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.4566
# Epoch 00057: val_loss improved from 16.94825 to 16.91992, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 580us/sample - loss: 16.7078 - val_loss: 16.9199
# Epoch 58/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7930
# Epoch 00058: val_loss did not improve from 16.91992
# 120/120 [==============================] - 0s 415us/sample - loss: 16.7010 - val_loss: 16.9235
# Epoch 59/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.5277
# Epoch 00059: val_loss did not improve from 16.91992
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 120/120 [==============================] - 0s 414us/sample - loss: 16.6855 - val_loss: 16.9369
# Epoch 60/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8016
# Epoch 00060: val_loss improved from 16.91992 to 16.90331, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 562us/sample - loss: 16.6716 - val_loss: 16.9033
# Epoch 61/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.4669
# Epoch 00061: val_loss did not improve from 16.90331
# 120/120 [==============================] - 0s 426us/sample - loss: 16.6801 - val_loss: 16.9073
# Epoch 62/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8881
# Epoch 00062: val_loss improved from 16.90331 to 16.89973, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 563us/sample - loss: 16.6880 - val_loss: 16.8997
# Epoch 63/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.8611
# Epoch 00063: val_loss did not improve from 16.89973
# 120/120 [==============================] - 0s 414us/sample - loss: 16.6657 - val_loss: 16.9030
# Epoch 64/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.7932
# Epoch 00064: val_loss did not improve from 16.89973
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 120/120 [==============================] - 0s 410us/sample - loss: 16.6600 - val_loss: 16.9069
# Epoch 65/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.7448
# Epoch 00065: val_loss improved from 16.89973 to 16.89571, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 553us/sample - loss: 16.6589 - val_loss: 16.8957
# Epoch 66/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.6292
# Epoch 00066: val_loss did not improve from 16.89571
# 120/120 [==============================] - 0s 430us/sample - loss: 16.6559 - val_loss: 16.8984
# Epoch 67/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.5318
# Epoch 00067: val_loss improved from 16.89571 to 16.88943, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 567us/sample - loss: 16.6533 - val_loss: 16.8894
# Epoch 68/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.1320
# Epoch 00068: val_loss improved from 16.88943 to 16.88914, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 569us/sample - loss: 16.6505 - val_loss: 16.8891
# Epoch 69/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.5035
# Epoch 00069: val_loss did not improve from 16.88914
# 120/120 [==============================] - 0s 417us/sample - loss: 16.6531 - val_loss: 16.8937
# Epoch 70/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.7031
# Epoch 00070: val_loss improved from 16.88914 to 16.88889, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 572us/sample - loss: 16.6477 - val_loss: 16.8889
# Epoch 71/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.0508
# Epoch 00071: val_loss improved from 16.88889 to 16.88519, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 579us/sample - loss: 16.6480 - val_loss: 16.8852
# Epoch 72/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.1668
# Epoch 00072: val_loss did not improve from 16.88519
# 120/120 [==============================] - 0s 412us/sample - loss: 16.6464 - val_loss: 16.8852
# Epoch 73/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.1744
# Epoch 00073: val_loss improved from 16.88519 to 16.88424, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 562us/sample - loss: 16.6458 - val_loss: 16.8842
# Epoch 74/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.6753
# Epoch 00074: val_loss improved from 16.88424 to 16.88290, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 570us/sample - loss: 16.6440 - val_loss: 16.8829
# Epoch 75/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.1105
# Epoch 00075: val_loss did not improve from 16.88290
# 120/120 [==============================] - 0s 412us/sample - loss: 16.6442 - val_loss: 16.8840
# Epoch 76/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.4373
# Epoch 00076: val_loss did not improve from 16.88290
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 120/120 [==============================] - 0s 412us/sample - loss: 16.6416 - val_loss: 16.8880
# Epoch 77/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.5212
# Epoch 00077: val_loss did not improve from 16.88290
# 120/120 [==============================] - 0s 405us/sample - loss: 16.6403 - val_loss: 16.8839
# Epoch 78/200
#  20/120 [====>.........................] - ETA: 0s - loss: 17.3657
# Epoch 00078: val_loss improved from 16.88290 to 16.88020, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 574us/sample - loss: 16.6388 - val_loss: 16.8802
# Epoch 79/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.9135
# Epoch 00079: val_loss improved from 16.88020 to 16.87653, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# 120/120 [==============================] - 0s 558us/sample - loss: 16.6382 - val_loss: 16.8765
# Epoch 80/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.4406
# Epoch 00080: val_loss did not improve from 16.87653
# 120/120 [==============================] - 0s 407us/sample - loss: 16.6386 - val_loss: 16.8772
# Epoch 81/200
#  20/120 [====>.........................] - ETA: 0s - loss: 18.1978
# Epoch 00081: val_loss did not improve from 16.87653
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 120/120 [==============================] - 0s 402us/sample - loss: 16.6377 - val_loss: 16.8787
# Epoch 82/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.5225
# Epoch 00082: val_loss did not improve from 16.87653
# 120/120 [==============================] - 0s 401us/sample - loss: 16.6369 - val_loss: 16.8790
# Epoch 83/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.8532
# Epoch 00083: val_loss did not improve from 16.87653
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 120/120 [==============================] - 0s 407us/sample - loss: 16.6367 - val_loss: 16.8793
# Epoch 84/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.1157
# Epoch 00084: val_loss did not improve from 16.87653
# 120/120 [==============================] - 0s 420us/sample - loss: 16.6365 - val_loss: 16.8792
# Epoch 85/200
#  20/120 [====>.........................] - ETA: 0s - loss: 19.0380
# Epoch 00085: val_loss did not improve from 16.87653
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 1e-05.
# 120/120 [==============================] - 0s 401us/sample - loss: 16.6368 - val_loss: 16.8784
# Epoch 86/200
#  20/120 [====>.........................] - ETA: 0s - loss: 15.4782
# Epoch 00086: val_loss did not improve from 16.87653
# 120/120 [==============================] - 0s 397us/sample - loss: 16.6364 - val_loss: 16.8783
# Epoch 87/200
#  20/120 [====>.........................] - ETA: 0s - loss: 16.0241
# Epoch 00087: val_loss did not improve from 16.87653
# 120/120 [==============================] - 0s 406us/sample - loss: 16.6364 - val_loss: 16.8782
# Epoch 00087: early stopping
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F024/test/F024_WY_2018_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F024/validate/F024_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/train/F024_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/validate/F024_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/train/F024_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F024/validate/F024_WY_2017_500mb.nc"...
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 72, 60, 6)    0           input_15[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Train on 240 samples, validate on 120 samples
# Epoch 1/200
#  20/240 [=>............................] - ETA: 5s - loss: 146.3587
# Epoch 00001: val_loss improved from inf to 28.67741, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 1s 3ms/sample - loss: 91.9903 - val_loss: 28.6774
# Epoch 2/200
#  20/240 [=>............................] - ETA: 0s - loss: 27.4755
# Epoch 00002: val_loss did not improve from 28.67741
# 240/240 [==============================] - 0s 300us/sample - loss: 30.0685 - val_loss: 31.0700
# Epoch 3/200
#  20/240 [=>............................] - ETA: 0s - loss: 31.2643
# Epoch 00003: val_loss improved from 28.67741 to 21.50454, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 375us/sample - loss: 25.5975 - val_loss: 21.5045
# Epoch 4/200
#  20/240 [=>............................] - ETA: 0s - loss: 22.4894
# Epoch 00004: val_loss improved from 21.50454 to 20.46661, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 368us/sample - loss: 21.5633 - val_loss: 20.4666
# Epoch 5/200
#  20/240 [=>............................] - ETA: 0s - loss: 21.5305
# Epoch 00005: val_loss improved from 20.46661 to 19.73844, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 20.3467 - val_loss: 19.7384
# Epoch 6/200
#  20/240 [=>............................] - ETA: 0s - loss: 19.0279
# Epoch 00006: val_loss improved from 19.73844 to 18.79532, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 19.3981 - val_loss: 18.7953
# Epoch 7/200
#  20/240 [=>............................] - ETA: 0s - loss: 19.3309
# Epoch 00007: val_loss improved from 18.79532 to 17.86436, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 367us/sample - loss: 18.2543 - val_loss: 17.8644
# Epoch 8/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.5066
# Epoch 00008: val_loss improved from 17.86436 to 17.55025, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 369us/sample - loss: 17.7387 - val_loss: 17.5503
# Epoch 9/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.8201
# Epoch 00009: val_loss improved from 17.55025 to 17.33664, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 364us/sample - loss: 17.4645 - val_loss: 17.3366
# Epoch 10/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.4854
# Epoch 00010: val_loss improved from 17.33664 to 17.17771, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 361us/sample - loss: 17.2678 - val_loss: 17.1777
# Epoch 11/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.4126
# Epoch 00011: val_loss improved from 17.17771 to 17.04470, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 360us/sample - loss: 17.1208 - val_loss: 17.0447
# Epoch 12/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.6571
# Epoch 00012: val_loss improved from 17.04470 to 16.94781, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 359us/sample - loss: 17.0038 - val_loss: 16.9478
# Epoch 13/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.0744
# Epoch 00013: val_loss improved from 16.94781 to 16.92684, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 372us/sample - loss: 16.9352 - val_loss: 16.9268
# Epoch 14/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.7544
# Epoch 00014: val_loss improved from 16.92684 to 16.82075, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 16.8904 - val_loss: 16.8207
# Epoch 15/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.3518
# Epoch 00015: val_loss did not improve from 16.82075
# 240/240 [==============================] - 0s 294us/sample - loss: 16.8222 - val_loss: 16.8229
# Epoch 16/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.6643
# Epoch 00016: val_loss improved from 16.82075 to 16.75315, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 372us/sample - loss: 16.7867 - val_loss: 16.7531
# Epoch 17/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.5358
# Epoch 00017: val_loss improved from 16.75315 to 16.71933, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 373us/sample - loss: 16.7961 - val_loss: 16.7193
# Epoch 18/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.5028
# Epoch 00018: val_loss did not improve from 16.71933
# 240/240 [==============================] - 0s 293us/sample - loss: 16.7438 - val_loss: 16.7871
# Epoch 19/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.9243
# Epoch 00019: val_loss improved from 16.71933 to 16.71690, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 16.7488 - val_loss: 16.7169
# Epoch 20/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.3220
# Epoch 00020: val_loss improved from 16.71690 to 16.71495, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 370us/sample - loss: 16.7278 - val_loss: 16.7149
# Epoch 21/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.2955
# Epoch 00021: val_loss improved from 16.71495 to 16.66237, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 362us/sample - loss: 16.6957 - val_loss: 16.6624
# Epoch 22/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.5043
# Epoch 00022: val_loss improved from 16.66237 to 16.65361, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 16.6885 - val_loss: 16.6536
# Epoch 23/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.1591
# Epoch 00023: val_loss improved from 16.65361 to 16.64706, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 363us/sample - loss: 16.6726 - val_loss: 16.6471
# Epoch 24/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.9620
# Epoch 00024: val_loss improved from 16.64706 to 16.63552, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 368us/sample - loss: 16.6682 - val_loss: 16.6355
# Epoch 25/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.8684
# Epoch 00025: val_loss did not improve from 16.63552
# 240/240 [==============================] - 0s 296us/sample - loss: 16.6654 - val_loss: 16.6373
# Epoch 26/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.4760
# Epoch 00026: val_loss improved from 16.63552 to 16.63162, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 364us/sample - loss: 16.6685 - val_loss: 16.6316
# Epoch 27/200
#  20/240 [=>............................] - ETA: 0s - loss: 19.5337
# Epoch 00027: val_loss improved from 16.63162 to 16.62078, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 364us/sample - loss: 16.6834 - val_loss: 16.6208
# Epoch 28/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.1599
# Epoch 00028: val_loss did not improve from 16.62078
# 240/240 [==============================] - 0s 291us/sample - loss: 16.7035 - val_loss: 16.6536
# Epoch 29/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.7675
# Epoch 00029: val_loss did not improve from 16.62078
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 240/240 [==============================] - 0s 291us/sample - loss: 16.6493 - val_loss: 16.6398
# Epoch 30/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.3619
# Epoch 00030: val_loss improved from 16.62078 to 16.60388, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 366us/sample - loss: 16.6395 - val_loss: 16.6039
# Epoch 31/200
#  20/240 [=>............................] - ETA: 0s - loss: 14.7233
# Epoch 00031: val_loss did not improve from 16.60388
# 240/240 [==============================] - 0s 295us/sample - loss: 16.6350 - val_loss: 16.6043
# Epoch 32/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.7911
# Epoch 00032: val_loss did not improve from 16.60388
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 240/240 [==============================] - 0s 290us/sample - loss: 16.6242 - val_loss: 16.6156
# Epoch 33/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.9630
# Epoch 00033: val_loss improved from 16.60388 to 16.59766, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 364us/sample - loss: 16.6221 - val_loss: 16.5977
# Epoch 34/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.2776
# Epoch 00034: val_loss did not improve from 16.59766
# 240/240 [==============================] - 0s 291us/sample - loss: 16.6187 - val_loss: 16.6004
# Epoch 35/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.2054
# Epoch 00035: val_loss improved from 16.59766 to 16.59495, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 364us/sample - loss: 16.6223 - val_loss: 16.5950
# Epoch 36/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.6924
# Epoch 00036: val_loss improved from 16.59495 to 16.59372, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 368us/sample - loss: 16.6156 - val_loss: 16.5937
# Epoch 37/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.7707
# Epoch 00037: val_loss improved from 16.59372 to 16.58964, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 370us/sample - loss: 16.6160 - val_loss: 16.5896
# Epoch 38/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.2345
# Epoch 00038: val_loss did not improve from 16.58964
# 240/240 [==============================] - 0s 293us/sample - loss: 16.6164 - val_loss: 16.5933
# Epoch 39/200
#  20/240 [=>............................] - ETA: 0s - loss: 14.6255
# Epoch 00039: val_loss did not improve from 16.58964
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 240/240 [==============================] - 0s 290us/sample - loss: 16.6139 - val_loss: 16.5898
# Epoch 40/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.8196
# Epoch 00040: val_loss improved from 16.58964 to 16.58481, saving model to /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F024/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# 240/240 [==============================] - 0s 361us/sample - loss: 16.6130 - val_loss: 16.5848
# Epoch 41/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.2517
# Epoch 00041: val_loss did not improve from 16.58481
# 240/240 [==============================] - 0s 293us/sample - loss: 16.6097 - val_loss: 16.5884
# Epoch 42/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.6920
# Epoch 00042: val_loss did not improve from 16.58481
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 240/240 [==============================] - 0s 290us/sample - loss: 16.6086 - val_loss: 16.5874
# Epoch 43/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.8194
# Epoch 00043: val_loss did not improve from 16.58481
# 240/240 [==============================] - 0s 288us/sample - loss: 16.6076 - val_loss: 16.5864
# Epoch 44/200
#  20/240 [=>............................] - ETA: 0s - loss: 15.7044
# Epoch 00044: val_loss did not improve from 16.58481
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 240/240 [==============================] - 0s 292us/sample - loss: 16.6073 - val_loss: 16.5869
# Epoch 45/200
#  20/240 [=>............................] - ETA: 0s - loss: 18.6647
# Epoch 00045: val_loss did not improve from 16.58481
# 240/240 [==============================] - 0s 292us/sample - loss: 16.6071 - val_loss: 16.5860
# Epoch 46/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.1287
# Epoch 00046: val_loss did not improve from 16.58481
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-05.
# 240/240 [==============================] - 0s 292us/sample - loss: 16.6070 - val_loss: 16.5861
# Epoch 47/200
#  20/240 [=>............................] - ETA: 0s - loss: 17.4736
# Epoch 00047: val_loss did not improve from 16.58481
# 240/240 [==============================] - 0s 287us/sample - loss: 16.6068 - val_loss: 16.5853
# Epoch 48/200
#  20/240 [=>............................] - ETA: 0s - loss: 16.0557
# Epoch 00048: val_loss did not improve from 16.58481
# 240/240 [==============================] - 0s 291us/sample - loss: 16.6068 - val_loss: 16.5857
# Epoch 00048: early stopping

# %% [markdown]
# # Look at the Improvements?

# %%
All_file_names

All_file_names

allinds = np.arange(len(res))

ense = 21
numbins = 15
allinds = np.arange(len(All_file_names))


avgvar_mA = np.zeros([len(All_file_names),numbins])
msebin_mA = np.zeros([len(All_file_names),numbins])
avgvar_sA = np.zeros([len(All_file_names),numbins])
msebin_sA = np.zeros([len(All_file_names),numbins])

mAl =np.array([])
sAl =np.array([])
yAl =np.array([])
wwrfAl = np.array([])
latoutAl = np.array([])
lonoutAl = np.array([])
tout = np.array([],dtype='datetime64[ns]')

print('######### ASSEMBLE!!!! ###########')
#find lat/lons of interest:
rang = 144
latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/'
[latsDO,lonsDO,latind, lonind] = utilsProbSS.get_latlon_ind(latlonfolder)
latsDO.shape
latind = np.array(latind[:rang])
lonind = np.array(lonind[:rang])
latsDO = np.array(latsDO[:rang])
lonsDO = np.array(lonsDO[:rang])
print('########### DONE!!!! #############')



for ddfa, bb in enumerate(range(len(res)-3,len(res))):
    
    if bb == (len(res)-1):
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[-3]]]
        val_fil_name = [res[allinds[-1]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    else:
        allinds = np.arange(len(res))
        test_fil_name = [res[allinds[bb+1]]]
        val_fil_name = [res[allinds[bb]]]
        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(res)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utils_CNN.deep_learning_generator(train_fil_name, num_samps_train,norm_dict,norm_dict_targ)
    adf = next(aa)
    x = adf[0]
    y = adf[1]

    aa = utils_CNN.deep_learning_generator_nordnm(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]
    
    
#     ### Model Build #### 
    img_height = x.shape[1]
    img_width = x.shape[2]
    num_channels = x.shape[3]
    img_shape = (img_height, img_width, num_channels)
    nummy_classes = 2

    model = Unet_b.model_simple_unet_initializer(img_shape=img_shape, cost_func=crps_cost_function,num_classes=nummy_classes,num_levels = 1,num_layers =2, num_bottleneck = 3, filter_size_start =16, batch_norm=None, kernel_size = 3, 
                                     bottleneck_dilation = True, bottleneck_sum_activation =False)

    newout  = tf.keras.layers.Conv2D(32, 3, activation='relu',padding='same')(model.layers[-1].output)
    newout  = tf.keras.layers.Conv2D(2, 3, activation='linear',padding='same')(newout)
    model = tf.keras.models.Model(inputs = model.inputs, outputs = newout)
    opt = optimizer=tf.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer='adam', loss=crps_cost_function)
    model.summary()
    
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
#     #save location:
    
    newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/CNN_'+tstyr
    Wsave_name = newdir+'/cpf_CRPS_FINETUNE_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    print('########### Loading old model weights name:',Wsave_name)
    model.load_weights(Wsave_name)
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    
    
    yhat = model(x_tst)
    yhat = yhat.numpy()
    
    m = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    m2 = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    mm = np.ndarray.flatten(yhat[:,latind,lonind,0],order='F')
    s = np.abs(np.ndarray.flatten(yhat[:,latind,lonind,1],order='F'))
    
    WWRF = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
    WWRF = np.ndarray.flatten(WWRF[:,latind,lonind],order='F')
    
    y_tst = (utilsProbSS.denormalize_images_targ(np.ndarray.flatten(y_tst[:,latind,lonind,0],order='F'),'IVTm',norm_dict_targ))
    y_tst=np.expand_dims(y_tst,axis=1)
    
    #gather other variables of interest (time and lat/lon)
    op = xr.open_dataset(test_fil_name[0])
    lat = op['lat'][:].data
    lon = op['lon'][:].data
    lat_out = np.ndarray.flatten(np.matlib.repmat(lat[latind],x_tst.shape[0],1),order='F')
    lon_out = np.ndarray.flatten(np.matlib.repmat(lon[lonind],x_tst.shape[0],1),order='F')
    time_out = np.ndarray.flatten(np.matlib.repmat(op['time'][:].data,latind.shape[0],1)) 
    

    #form ensembles 
    m_All = np.zeros(len(m))
    sss_All = np.zeros([len(m),ense])
    s_All = np.zeros(len(m))
    
    
    for ii in range(len(m)):
        sss = np.random.normal(m[ii],s[ii],ense)
        sln=np.std(sss)
        mln=np.mean(sss)
        [mln,sln]=lognstat(m[ii],s[ii])
        s_All[ii]=s[ii]
        m_All[ii]=m[ii]
        sss_All[ii,:] =(sss) 

    m = m_All
    m[np.isnan(m)]=0
    s=s_All
    s[np.isnan(m)]=0
    
    y_tst = (y_tst)
    WWRF = (WWRF)
    distPP = s
    
    if ddfa == 0:
        sssAl = sss_All
    else: 
        sssAl = np.concatenate([sssAl,sss_All],axis=0)
    
    
    if bb == (len(res)-1):
        mAl = np.append(np.ndarray.flatten(m),mAl)
        yAl = np.append(np.ndarray.flatten(y_tst),yAl)
        sAl = np.append(np.ndarray.flatten(s),sAl)
        wwrfAl = np.append(np.ndarray.flatten(WWRF),wwrfAl)
        latoutAl = np.append(np.ndarray.flatten(lat_out),latoutAl)
        lonoutAl = np.append(np.ndarray.flatten(lon_out),lonoutAl)
        tout = np.append(np.ndarray.flatten(time_out),tout)
    else:
        mAl = np.append(mAl,np.ndarray.flatten(m))
        yAl = np.append(yAl,np.ndarray.flatten(y_tst))
        sAl = np.append(sAl,np.ndarray.flatten(s))
        wwrfAl = np.append(wwrfAl,np.ndarray.flatten(WWRF))
        latoutAl = np.append(latoutAl,np.ndarray.flatten(lat_out))
        lonoutAl = np.append(lonoutAl,np.ndarray.flatten(lon_out))
        tout = np.append(tout,np.ndarray.flatten(time_out))
    
    print('...binned spread skill...')
    [avgvar_m,msebin_m,avgvar_s,msebin_s]=spreadskill(m,y_tst,distPP,numbins)
    
    avgvar_mA[bb,:] = np.squeeze(avgvar_m)
    msebin_mA[bb,:] = np.squeeze(msebin_m)
    avgvar_sA[bb,:] = np.squeeze(avgvar_s)
    msebin_sA[bb,:] = np.squeeze(msebin_s)
    
    plt.figure(figsize=[15,10])  # inches
    plt.errorbar(avgvar_m, (msebin_m), xerr=avgvar_s, yerr=msebin_s, uplims=True, lolims=True,color='r',linewidth=2)
    plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
    plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

    plt.tick_params(axis='x', labelsize=15)
    plt.tick_params(axis='y', labelsize=15)
    plt.title('Spread Skill Plot',fontsize=25)

    plt.plot([0,140],[0,140],'k--')
    plt.show()
    
    print('RMSE PP:',rmse(np.expand_dims(m,axis=1),y_tst))
    print('RMSE WWRF:',rmse(np.expand_dims(WWRF,axis=1),y_tst))
    print('CRMSE PP:',crmse(np.expand_dims(m,axis=1),y_tst))
    print('CRMSE WWRF:',crmse(np.expand_dims(WWRF,axis=1),y_tst))
    print('BIAS PP:',bias(np.expand_dims(m,axis=1),y_tst))
    print('BIAS WWRF:',bias(np.expand_dims(WWRF,axis=1),y_tst))
    
newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/Reforecast_out/'
print('IVTm shape:', yAl.shape)
print('IVT mean shape:', mAl.shape)
print('IVT std shape:', sAl.shape)

df_out = pd.DataFrame({'time':tout,'OBS':yAl,'Model':wwrfAl,'IVTmean':mAl,'IVTstd':sAl,'lat':latoutAl,'lon':lonoutAl})
df_out.to_pickle(newdir+'NN_CRPS_CNNPP_FINETUNEref2.pkl')
np.savez(newdir+'NN_CRPS_CNNPP_FINETUNEref2.npz',lat=lat,lon=lon,IVTgefsm=mAl,IVTgefss=sAl,IVTm_gefs=yAl)
# Out:
# ######### ASSEMBLE!!!! ###########
# ########### DONE!!!! #############
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 72, 60, 6)    0           input_20[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_19[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_19[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_19 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Model: "model_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 72, 60, 6)    0           input_20[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_19[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_19[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_19 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 71, 57, 32)   608         cropping2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 71, 57, 2)    578         conv2d[0][0]
# ==================================================================================================
# Total params: 36,692
# Trainable params: 36,628
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2017/cpf_CRPS_FINETUNE_val_2016_test_2017.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# ...binned spread skill...
# RMSE PP: 44.18309312326658
# RMSE WWRF: 47.8084413890903
# CRMSE PP: 44.177343659646255
# CRMSE WWRF: 47.509044735597186
# BIAS PP: 0.7127496616847111
# BIAS WWRF: 5.3420563
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# Model: "model_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 72, 60, 6)    0           input_21[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_20[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_20 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Model: "model_22"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 72, 60, 6)    0           input_21[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_20[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_20 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 71, 57, 32)   608         cropping2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 71, 57, 2)    578         conv2d_2[0][0]
# ==================================================================================================
# Total params: 36,692
# Trainable params: 36,628
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2018/cpf_CRPS_FINETUNE_val_2017_test_2018.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# ...binned spread skill...
# RMSE PP: 45.65416240477951
# RMSE WWRF: 52.847082734926246
# CRMSE PP: 45.57387793217876
# CRMSE WWRF: 52.659766796108855
# BIAS PP: -2.706333461985423
# BIAS WWRF: 4.445526
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:45: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py:209: RuntimeWarning: divide by zero encountered in log
#   predictor_matrix[:,:,:,indicesPRED] = numpy.log(predictor_matrix[:,:,:,indicesPRED])
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/test/F048_WY_2018_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/validate/F048_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F048/train/F048_WY_2016_500mb.nc"...
# Model: "model_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 72, 60, 6)    0           input_22[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_21[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_21[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_21 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# ==================================================================================================
# Total params: 35,506
# Trainable params: 35,442
# Non-trainable params: 64
# __________________________________________________________________________________________________
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           [(None, 71, 57, 6)]  0
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 72, 60, 6)    0           input_22[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_0 (Conv2D)  (None, 72, 60, 16)   880         zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_0 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_0 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_conv_1 (Conv2D)  (None, 72, 60, 16)   2320        downsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# downsampling_0_batchnorm_1 (Bat (None, 72, 60, 16)   64          downsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# downsampling_0_activation_1 (Ac (None, 72, 60, 16)   0           downsampling_0_batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 36, 30, 16)   0           downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_0 (Conv2D)      (None, 36, 30, 32)   4640        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_1 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_0[0][0]
# __________________________________________________________________________________________________
# bottleneck_skip_2 (Conv2D)      (None, 36, 30, 32)   9248        bottleneck_skip_1[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 36, 30, 32)   0           bottleneck_skip_0[0][0]
#                                                                  bottleneck_skip_1[0][0]
#                                                                  bottleneck_skip_2[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_trans_0 (Conv (None, 72, 60, 16)   2064        add_21[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 72, 60, 32)   0           upsampling_0_conv_trans_0[0][0]
#                                                                  downsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_0 (Conv2D)    (None, 72, 60, 16)   4624        concatenate_21[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_0 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_conv_1 (Conv2D)    (None, 72, 60, 16)   2320        upsampling_0_activation_0[0][0]
# __________________________________________________________________________________________________
# upsampling_0_activation_1 (Acti (None, 72, 60, 16)   0           upsampling_0_conv_1[0][0]
# __________________________________________________________________________________________________
# linear (Conv2D)                 (None, 72, 60, 2)    34          upsampling_0_activation_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_21 (Cropping2D)      (None, 71, 57, 2)    0           linear[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 57, 32)   608         cropping2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 71, 57, 2)    578         conv2d_4[0][0]
# ==================================================================================================
# Total params: 36,692
# Trainable params: 36,628
# Non-trainable params: 64
# __________________________________________________________________________________________________
# ########### Loading old model weights name: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F048/CNN_2016/cpf_CRPS_FINETUNE_val_2018_test_2016.ckpt
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:432: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in exp
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/ipykernel_launcher.py:433: RuntimeWarning: overflow encountered in double_scalars
# ...binned spread skill...
# RMSE PP: 54.54018466680812
# RMSE WWRF: 60.98833967909431
# CRMSE PP: 54.27597840666324
# CRMSE WWRF: 60.98037974015934
# BIAS PP: -5.361904697703153
# BIAS WWRF: 0.9853058
# IVTm shape: (51408,)
# IVT mean shape: (51408,)
# IVT std shape: (51408,)

# %%
df_out
# Out:
#             time         OBS       Model     IVTmean     IVTstd   lat      lon
# 0     2016-12-03  133.404922  195.706635  157.874725  33.254486  30.0 -116.875
# 1     2016-12-04  159.502472  124.271339  110.263062  23.774370  30.0 -116.875
# 2     2016-12-05  554.820190  516.225037  458.655518  79.385246  30.0 -116.875
# 3     2016-12-06  182.650604  285.746429  248.820755  61.722282  30.0 -116.875
# 4     2016-12-07   64.148026   65.660843   59.227394  16.043854  30.0 -116.875
# ...          ...         ...         ...         ...        ...   ...      ...
# 51403 2019-03-27   51.296139   54.579849   41.214165  12.273033  55.0 -130.000
# 51404 2019-03-28   73.146805  116.416245   76.847458  27.056286  55.0 -130.000
# 51405 2019-03-29   61.858551   49.954445   43.114113  18.669382  55.0 -130.000
# 51406 2019-03-30   54.374878   86.608208   54.933849  21.453461  55.0 -130.000
# 51407 2019-03-31   78.836029  104.195099   78.224960  32.193527  55.0 -130.000
#
# [51408 rows x 7 columns]

# %%
import properscoring as ps
distPPT = (np.squeeze(sAl))
print('...binned spread skill...')
[avgvar_mT,msebin_mT,avgvar_sT,msebin_sT]=spreadskill(mAl,yAl,distPPT,numbins)
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/Spread_Skill_CRPS.npz',mAl=mAl,yAl=yAl,distPPT=distPPT,
#                     numbins=numbins,avgvar_mA=avgvar_mA,msebin_mA=msebin_mA,avgvar_sA=avgvar_sA,msebin_sA=msebin_sA)

crps_ense = ps.crps_ensemble(np.squeeze(yAl[yAl>250]),sssAl[np.squeeze([yAl>250][0][:]),:])
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/twCRPS_CRPS.npz',yAl=yAl,sssAl=sssAl,crps_ense=crps_ense)


plt.figure(figsize=[15,10])  # inches
mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()

evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]
    
plt.errorbar(avgvar_mT, msebin_mT, xerr=3*avgvar_sT, yerr=3*msebin_sT, uplims=True, lolims=True,linewidth=4,color='k',alpha=1,label='Full Dataset')
plt.legend(fontsize=20)
plt.plot([0,180],[0,180],linestyle='--',linewidth=3,color=[0.5,0.5,0.5])

plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('Boost Spread Skill Plot',fontsize=25)
# cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
# cb.ax.tick_params(labelsize=20) 
plt.xlim([0,200])
plt.ylim([0,200])

plt.show()
# Out:
# ...binned spread skill...

# %%
distPP = np.ndarray.flatten(distPP)
guess = np.ndarray.flatten(m)
truth = np.ndarray.flatten(y_tst)
indexsort = np.argsort(distPP)
err = (guess-truth)**2
varianceall = distPP[indexsort]
err_sort = err[indexsort]


plt.figure(figsize=(15,10))
plt.plot(np.sqrt(err_sort))
plt.show()

# %% [markdown]
# # RANK HISTOGRAM

# %%
Thresher = 250 #thresh to stratify on. 
rr2 = ranker(yAl[mAl>Thresher],np.transpose(sssAl[mAl>Thresher]))

print('making figure... takes FOREVER')
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
# plt.hist(rr,density=True,bins=30,alpha=0.4,label='AnEn')
plt.hist(rr2,density=True,bins=22,alpha=0.4,label='CRPS',color='k')
plt.plot([-10,80],[0.047,0.047],'k--')
plt.legend(fontsize=26)
plt.ylim([0,0.2])
plt.xlim([0,23])
# plt.savefig('/glade/scratch/wchapman/Reforecast/models/RankHist_'+fcast+'_ThreshOBS250_ForecastHour.png',dpi = 300,bbox_inches='tight')
plt.show()
# Out:
# computing ranks
# computing ties
# making figure... takes FOREVER

# %%
_set = []
_transformed_set = []
 
num_ense=200
for ii in range(yAl.shape[0]):
    texpp = cdf_of_normal(yAl[ii],mAl[ii],sAl[ii])
    _transformed_set.append(texpp)
   
print('...making figure...')
plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
plt.hist(_transformed_set,density=True,bins=16,alpha=0.4,label='CNN_CRPS',color='k')
plt.plot([-10,80],[1,1],'k--')
plt.legend(fontsize=26)
plt.ylim([0,4])
plt.xlim([0,1])
plt.xticks(fontsize=19)
plt.yticks(fontsize=19)

plt.show()
# Out:
# ...making figure...

# %% [markdown]
# # Make Some Pretty Plots:

# %%
aa = utils_CNN.deep_learning_generator_nordnm(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
adf = next(aa)
x_tst = adf[0]
y_tst = adf[1]
times = adf[2]
ARcnn_prob= model.predict(x_tst)
WWRF_f = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
PPP = Dataset("/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc")
lat = PPP['lat'][:].data
lon = PPP['lon'][:].data
# Out:
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc"...

# %%
num=76
print('showing:', times[num])
[XX,YY]=np.meshgrid(lon-180,lat)
clevs = np.linspace(0, 700, 21)
clevs_diff = np.linspace(-300, 300, 21)

contlevs = np.linspace(10,200, 20)

plt.figure(figsize=(28, 15))
proj = ccrs.PlateCarree(central_longitude=180)
ax1 = plt.subplot(2, 3, 1, projection=proj)
ax1.coastlines('50m')
plt.contourf(lon-180, lat, ARcnn_prob[num,:,:,0].squeeze(), levels=clevs,
            cmap=plt.cm.Blues, transform=proj,extend='max')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax1.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax1.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax1.xaxis.set_major_formatter(lon_formatter)
ax1.yaxis.set_major_formatter(lat_formatter)
ax1.tick_params(labelsize=20) 
ax1.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
aa=plt.title('IVT and Spread', fontsize=25)
plt.contour(lon-180, lat, np.abs(ARcnn_prob[num,:,:,1].squeeze()), levels=contlevs[::2],cmap='Reds',linewidths=1)
plt.contour(lon-180, lat, np.abs(ARcnn_prob[num,:,:,1].squeeze()), levels=[100,100.01],colors='k',linewidths=1)
########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

##### second figure ########

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

ax2 = plt.subplot(2, 3, 2, projection=proj)
ax2.coastlines('50m')
plt.contourf(lon-180, lat, WWRF_f[num,:,:].squeeze(), levels=clevs,
            cmap=plt.cm.Blues, transform=proj,extend='max')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax2.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax2.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax2.xaxis.set_major_formatter(lon_formatter)
ax2.yaxis.set_major_formatter(lat_formatter)
ax2.tick_params(labelsize=20) 
ax2.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
aa=plt.title('IVT and Spread', fontsize=25)

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

##### third figure ########

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

ax2 = plt.subplot(2, 3, 3, projection=proj)
ax2.coastlines('50m')
plt.contourf(lon-180, lat,y_tst[num,:,:].squeeze(), levels=clevs,
            cmap=plt.cm.Blues, transform=proj,extend='max')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax2.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax2.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax2.xaxis.set_major_formatter(lon_formatter)
ax2.yaxis.set_major_formatter(lat_formatter)
ax2.tick_params(labelsize=20) 
ax2.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
aa=plt.title('IVT and Spread', fontsize=25)

# plt.savefig('/Volumes/HotSlop/d4pdf/slp_monthly/IntVar/EOF1_Nino.png', dpi=200,bbox_inches='tight')


########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

##### fourth figure ########

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

ax2 = plt.subplot(2, 3, 4, projection=proj)
ax2.coastlines('50m')
plt.contourf(lon-180, lat,ARcnn_prob[num,:,:,0].squeeze()-y_tst[num,:,:].squeeze(), levels=clevs_diff,
            cmap=plt.cm.RdBu_r, transform=proj,extend='both')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax2.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax2.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax2.xaxis.set_major_formatter(lon_formatter)
ax2.yaxis.set_major_formatter(lat_formatter)
ax2.tick_params(labelsize=20) 
ax2.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
aa=plt.title('IVT and Spread', fontsize=25)

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

##### Fifth figure ########

########################################################################################################################################################
########################################################################################################################################################
########################################################################################################################################################

ax2 = plt.subplot(2, 3, 5, projection=proj)
ax2.coastlines('50m')
plt.contourf(lon-180, lat,WWRF_f[num,:,:].squeeze()-y_tst[num,:,:].squeeze(), levels=clevs_diff,
            cmap=plt.cm.RdBu_r, transform=proj,extend='both')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax2.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax2.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax2.xaxis.set_major_formatter(lon_formatter)
ax2.yaxis.set_major_formatter(lat_formatter)
ax2.tick_params(labelsize=20) 
ax2.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
aa=plt.title('IVT and Spread', fontsize=25)

# plt.savefig('/Volumes/HotSlop/d4pdf/slp_monthly/IntVar/EOF1_Nino.png', dpi=200,bbox_inches='tight')


plt.show()
# Out:
# showing: 2017-02-20 00:00:00

# %% [markdown]
# ## Can I mean variance scale this?

# %%
aa = utils_CNN.deep_learning_generator_nordnm(test_fil_name, num_samps_val,norm_dict,norm_dict_targ)
adf = next(aa)
x_tst = adf[0]
y_tst = adf[1]
times = adf[2]
ARcnn_prob= model.predict(x_tst)
WWRF_f = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
PPP = Dataset("/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc")
lat = PPP['lat'][:].data
lon = PPP['lon'][:].data

# %%
for bigcount, bb in enumerate(range(0,len(res))):
    allinds = np.arange(len(res))
    val_fil_name = [res[allinds[bb]]]
    rest = np.delete(allinds,[bb])
    train_fil_name = np.array(res)[rest].tolist()
        
    print('#################################################')
    print('training:',train_fil_name)
    print('validating:',val_fil_name)
    print('#################################################')
    
    for aa,f in enumerate(train_fil_name):    
        if aa==0:
            aa = utils_CNN.deep_learning_generator_nordnm([f], num_samps_val,norm_dict,norm_dict_targ)
            adf = next(aa)
            x_tst = adf[0]
            y_tst = np.squeeze(adf[1])
            times = adf[2]
            ARcnn_prob= model.predict(x_tst)
            WWRF_f = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)

            IVTrefs = ARcnn_prob
            IVTm_refs = y_tst
        else:
            aa = utils_CNN.deep_learning_generator_nordnm([f], num_samps_val,norm_dict,norm_dict_targ)
            adf = next(aa)
            x_tst = adf[0]
            y_tst = np.squeeze(adf[1])
            times = adf[2]
            ARcnn_prob= model.predict(x_tst)
            WWRF_f = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
            
            IVTrefs = np.concatenate([IVTrefs, ARcnn_prob],axis=0)
            IVTm_refs = np.concatenate([IVTm_refs, y_tst],axis=0)
            
    IVTrefsm = IVTrefs[:,:,:,0]
    IVTrefsv = IVTrefs[:,:,:,1]**2
    IVTrefsv = np.mean(IVTrefsv[:,latind,lonind],axis=0) #<s^2> 
        
        
    print('Training IVT shape:',IVTm_refs.shape)
    print('...Gathering Training...')
    MeanErrorREFS = np.zeros(len(latind))
    ErrVarEnseMeanTrainingREFS = np.zeros(len(latind))

    for rr in range(len(latind)):
        MeanErrorREFS[rr] = np.mean(IVTrefsm[:,latind[rr],lonind[rr]]- IVTm_refs[:,latind[rr],lonind[rr]],axis=0)
        ErrVarEnseMeanTrainingREFS[rr] =np.var(IVTrefsm[:,latind[rr],lonind[rr]] - IVTm_refs[:,latind[rr],lonind[rr]])
    
    ss = utils_CNN.deep_learning_generator_nordnm(val_fil_name, num_samps_val,norm_dict,norm_dict_targ)
    adf = next(ss)
    x_tst = adf[0]
    y_tst = adf[1]
    times = adf[2]
    ARcnn_prob2= model.predict(x_tst)
    WWRF_f = utilsProbSS.denormalize_images_targ((x_tst[:,:,:,0]),'IVT',norm_dict)
    
    IVTrefs_pp = ARcnn_prob2
    IVTmrefs_pp = y_tst
    
    IVTrefs_ppm = ARcnn_prob2[:,:,:,0]
    IVTrefs_ppv = ARcnn_prob2[:,:,:,1]**2
    
    for rr in range(len(latind)):
        IVTrefs_ppm[:,latind[rr],lonind[rr]] = IVTrefs_ppm[:,latind[rr],lonind[rr]]-MeanErrorREFS[rr];                             #debiased forecast.
        IVTrefs_ppv[:,latind[rr],lonind[rr]] = (IVTrefs_ppv[:,latind[rr],lonind[rr]]/IVTrefsv[rr])*ErrVarEnseMeanTrainingREFS[rr]  #variance corrected forecast. 
    
    
    if bigcount == 0:
        IVT_ppm_refs = np.ndarray.flatten(IVTrefs_ppm[:,latind,lonind])
        IVT_ppv_refs = np.ndarray.flatten(IVTrefs_ppv[:,latind,lonind])
        IVTm_pp_refs = np.ndarray.flatten(IVTmrefs_pp[:,latind,lonind]) 
    else: 
        IVT_ppm_refs = np.concatenate([IVT_ppm_refs,np.ndarray.flatten(IVTrefs_ppm[:,latind,lonind])],axis=0)
        IVT_ppv_refs = np.concatenate([IVT_ppv_refs,np.ndarray.flatten(IVTrefs_ppv[:,latind,lonind])],axis=0)
        IVTm_pp_refs = np.concatenate([IVTm_pp_refs,np.ndarray.flatten(IVTmrefs_pp[:,latind,lonind])],axis=0)
        
print('...done...')
    
newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/Reforecast_out/'
print('IVTm shape:', IVTm_pp_refs.shape)
print('IVT mean shape:', IVT_ppm_refs.shape)
print('IVT std shape:', IVT_ppv_refs.shape)

np.savez(newdir+'NN_CRPS_CNNPP_FINETUNEref2_MV.npz',lat=lat,lon=lon,IVTgefsm=IVT_ppm_refs,IVTgefss=np.sqrt(IVT_ppv_refs),IVTm_gefs=IVTm_pp_refs)
# Out:
# #################################################
# training: ['/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc', '/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc"...
# Training IVT shape: (232, 71, 57)
# ...Gathering Training...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc"...
# #################################################
# training: ['/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc', '/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc"...
# Training IVT shape: (232, 71, 57)
# ...Gathering Training...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc"...
# #################################################
# training: ['/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc', '/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/train/F120_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/validate/F120_WY_2017_500mb.nc"...
# Training IVT shape: (232, 71, 57)
# ...Gathering Training...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F120/test/F120_WY_2018_500mb.nc"...
# ...done...
# IVTm shape: (50112,)
# IVT mean shape: (50112,)
# IVT std shape: (50112,)

# %%
num_samps_val
# Out:
# 116

# %%
_set = []
_transformed_set = []
 
num_ense=200
for ii in range(IVTm_pp_refs.shape[0]):
    texpp = cdf_of_normal(IVTm_pp_refs[ii],IVT_ppm_refs[ii],np.sqrt(IVT_ppv_refs[ii]))
    _transformed_set.append(texpp)

plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
REFSmv_pp=plt.hist(_transformed_set,density=True,bins=21,alpha=0.4,label='REFS_pp',color='k')
plt.plot()
plt.plot([-10,80],[1,1],'k--')

plt.legend(fontsize=26)
plt.ylim([0,4])
plt.xlim([0,1])
plt.xticks(fontsize=19)
plt.yticks(fontsize=19)

plt.show()

# %% [markdown]
# ## GEFS

# %%
ff = Dataset('/glade/scratch/wchapman/GEFS/F072/WY_2016_GEFS_F072.nc')
IVTgefs = ff['IVT'][:].data
IVTm_gefs = ff['IVTm'][:].data
latgefs = ff['lat'][:]
longefs = ff['lon'][:]
timegefs = ff['time'][:].data



#time 
nctime = ff.variables['time'][:] # get values
t_unit = ff.variables['time'].units # get unit  "days since 1950-01-01T00:00:00Z"
t_cal = ff.variables['time'].calendar
timegefs = num2date(nctime,units = t_unit,calendar = t_cal)

# %%
print('showing:', timegefs[num-1])
plt.figure(figsize=(10, 10))

ax2 = plt.subplot(1, 1, 1, projection=proj)
ax2.coastlines('50m')
plt.contourf(longefs-180, latgefs,np.mean(IVTgefs[num-1,:,:,:],axis=0), levels=clevs,
            cmap=plt.cm.Blues, transform=proj,extend='both')


cc = plt.colorbar(shrink=0.75)

cc.ax.tick_params(labelsize=20) 
cc.set_label('[$kg m^{-1} s^{-1}$]',fontsize=20) 


ax2.set_xticks([120,150,180,210,240], crs=ccrs.PlateCarree())
ax2.set_yticks([20,30,40,50,60,70], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=True,
                                   number_format='.0f')
lat_formatter = LatitudeFormatter()
ax2.xaxis.set_major_formatter(lon_formatter)
ax2.yaxis.set_major_formatter(lat_formatter)
ax2.tick_params(labelsize=20) 
ax2.set_extent([200,250,20,65], crs=ccrs.PlateCarree())
plt.contour(longefs-180, latgefs, np.std(IVTgefs[num-1,:,:,:],axis=0), levels=contlevs[::2],cmap='Reds',linewidths=1)
plt.contour(longefs-180, latgefs, np.std(IVTgefs[num-1,:,:,:],axis=0), levels=[100,100.01],colors='k',linewidths=1)
aa=plt.title('IVT and Spread', fontsize=25)
# Out:
# showing: 2017-01-18 00:00:00

# %% [markdown]
# # Compare with GEFS:

# %%
print('We are here:',os.getcwd())
os.chdir('/glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/')
#reloading utils after changes:
importlib.reload(utilsProbSS)
importlib.reload(utilsProb)
# Out:
# We are here: /glade/scratch/wchapman/Reforecast/F048
# <module 'utilsProb' from '/glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/utilsProb.py'>

# %%
gefs_file_names = sorted([f for f in glob.glob("/glade/scratch/wchapman/GEFS/F048/*8.nc", recursive=True)])
for f in gefs_file_names:
    print(f)
# Out:
# /glade/scratch/wchapman/GEFS/F048/WY_2016_GEFS_F048.nc
# /glade/scratch/wchapman/GEFS/F048/WY_2017_GEFS_F048.nc
# /glade/scratch/wchapman/GEFS/F048/WY_2018_GEFS_F048.nc

# %%
latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/'
[latsDO,lonsDO,latind,lonind] = utilsProbSS.get_latlon_ind_gefs(latlonfolder)
latind = np.array(latind[:rang])
lonind = np.array(lonind[:rang])
latsDO = np.array(latsDO[:rang])
lonsDO = np.array(lonsDO[:rang])
latsDO.shape


for aa,f in enumerate(gefs_file_names):
    ff = Dataset(f)
    
    if aa==0:
        IVTgefs = ff['IVT'][:].data
        IVTm_gefs = ff['IVTm'][:].data
        latgefs = ff['lat'][:]
        longefs = ff['lon'][:]
    else: 
        IVTgefs = np.concatenate([IVTgefs, ff['IVT'][:].data],axis=0)
        IVTm_gefs = np.concatenate([IVTm_gefs, ff['IVTm'][:].data],axis=0)

# IVTens_gefs = np.reshape(np.swapaxes(IVTgefs[:,:,latind,lonind],1,2),[357*144,21])
# IVTm_gefs = np.ndarray.flatten(IVTm_gefs[:,latind,lonind])
# IVTgefs = IVTgefs[:,:,latind,lonind]
# IVTgefsm = np.ndarray.flatten(np.squeeze(np.mean(IVTgefs,axis=1)))
# IVTgefss = np.ndarray.flatten(np.squeeze(np.std(IVTgefs,axis=1)))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-269-3d7888a1d352> in <module>
#       9
#      10 for aa,f in enumerate(gefs_file_names[2]):
# ---> 11     ff = Dataset(f)
#      12
#      13     if aa==0:
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno 22] Invalid argument: b'/'

# %% [markdown]
# # Rank Histogram

# %%
Thresher = 20 #thresh to stratify on. 

rr2 = ranker(IVTm_gefs[IVTgefsm>Thresher],np.transpose(IVTens_gefs[IVTgefsm>Thresher]))

print('making figure... takes FOREVER')
plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
# plt.hist(rr,density=True,bins=30,alpha=0.4,label='AnEn')
plt.hist(rr2,density=True,bins=22,alpha=0.4,label='GEFS',color='k')
plt.plot([-10,80],[0.047,0.047],'k--')
plt.legend(fontsize=26)
plt.ylim([0,0.2])
plt.xlim([0,23])
# plt.savefig('/glade/scratch/wchapman/Reforecast/models/RankHist_'+fcast+'_ThreshOBS250_ForecastHour.png',dpi = 300,bbox_inches='tight')
plt.show()
# Out:
# computing ranks
# computing ties
# making figure... takes FOREVER

# %% [markdown]
# # PIT diagram

# %%
_set = []
_transformed_set = []
 
num_ense=200
for ii in range(IVTm_gefs.shape[0]):
    texpp = cdf_of_normal(IVTm_gefs[ii],IVTgefsm[ii],IVTgefss[ii])
    _transformed_set.append(texpp)
   
print('...making figure...')
plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
gefsPIT = plt.hist(_transformed_set,density=True,bins=16,alpha=0.4,label='GEFS',color='k')
plt.plot([-10,80],[1,1],'k--')
plt.legend(fontsize=26)
plt.ylim([0,5])
plt.xlim([0,1])
plt.xticks(fontsize=19)
plt.yticks(fontsize=19)

plt.show()
# Out:
# ...making figure...

# %% [markdown]
# ## Leave one out Mean and Variance Correct GEFS

# %%
print('We are here:',os.getcwd())
os.chdir('/glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal/')
#reloading utils after changes:
importlib.reload(utilsProbSS)
importlib.reload(utilsProb)

gefs_file_names = sorted([f for f in glob.glob("/glade/scratch/wchapman/GEFS/F048/*.nc", recursive=True)])
for f in gefs_file_names:
    print(f)
    
    
latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/WestCoast/'
[latsDO,lonsDO,latind,lonind] = utilsProbSS.get_latlon_ind_gefs(latlonfolder)
latind = np.array(latind[:rang])
lonind = np.array(lonind[:rang])
latsDO = np.array(latsDO[:rang])
lonsDO = np.array(lonsDO[:rang])
latsDO.shape



for bigcount, bb in enumerate(range(0,len(gefs_file_names))):

    allinds = np.arange(len(gefs_file_names))
    val_fil_name = [gefs_file_names[allinds[bb]]]
    rest = np.delete(allinds,[bb])
    train_fil_name = np.array(gefs_file_names)[rest].tolist()
        
    print('#################################################')
    print('training:',train_fil_name)
    print('validating:',val_fil_name)
    print('#################################################')
    
    for aa,f in enumerate(train_fil_name):
        ff = Dataset(f)
    
        if aa==0:
            IVTgefs = ff['IVT'][:].data
            IVTm_gefs = ff['IVTm'][:].data
        else: 
            IVTgefs = np.concatenate([IVTgefs, ff['IVT'][:].data],axis=0)
            IVTm_gefs = np.concatenate([IVTm_gefs, ff['IVTm'][:].data],axis=0)
            
    IVTgefsm = np.mean(IVTgefs,axis=1);
    IVTgefsv = np.var(IVTgefs,axis=1);
    IVTgefsv = np.mean(IVTgefsv[:,latind,lonind],axis=0) #<s^2> 
    
    print('Training IVT shape:',IVTm_gefs.shape)
    print('...Gathering Training...')
    MeanErrorGEFS = np.zeros(len(latind))
    ErrVarEnseMeanTrainingGEFS = np.zeros(len(latind))
    
    for rr in range(len(latind)):
        MeanErrorGEFS[rr] = np.mean(IVTgefsm[:,latind[rr],lonind[rr]]- IVTm_gefs[:,latind[rr],lonind[rr]],axis=0)
        ErrVarEnseMeanTrainingGEFS[rr] =np.var(IVTgefsm[:,latind[rr],lonind[rr]] - IVTm_gefs[:,latind[rr],lonind[rr]])
    
    datf=Dataset(val_fil_name[0])
    IVTgefs_pp = datf['IVT'][:].data
    IVTmgefs_pp = datf['IVTm'][:].data
    
    IVTgefs_ppm = np.mean(IVTgefs_pp,axis=1)
    IVTgefs_ppv = np.var(IVTgefs_pp,axis=1)
    
    for rr in range(len(latind)):
        IVTgefs_ppm[:,latind[rr],lonind[rr]] = IVTgefs_ppm[:,latind[rr],lonind[rr]]-MeanErrorGEFS[rr];                             #debiased forecast.
        IVTgefs_ppv[:,latind[rr],lonind[rr]] = (IVTgefs_ppv[:,latind[rr],lonind[rr]]/IVTgefsv[rr])*ErrVarEnseMeanTrainingGEFS[rr]  #variance corrected forecast. 
    
    
    if bigcount == 0:
        IVT_ppm_gefs = np.ndarray.flatten(IVTgefs_ppm[:,latind,lonind])
        IVT_ppv_gefs = np.ndarray.flatten(IVTgefs_ppv[:,latind,lonind])
        IVTm_pp_gefs = np.ndarray.flatten(IVTmgefs_pp[:,latind,lonind]) 
    else: 
        IVT_ppm_gefs = np.concatenate([IVT_ppm_gefs,np.ndarray.flatten(IVTgefs_ppm[:,latind,lonind])],axis=0)
        IVT_ppv_gefs = np.concatenate([IVT_ppv_gefs,np.ndarray.flatten(IVTgefs_ppv[:,latind,lonind])],axis=0)
        IVTm_pp_gefs = np.concatenate([IVTm_pp_gefs,np.ndarray.flatten(IVTmgefs_pp[:,latind,lonind])],axis=0)

# IVTens_gefs = np.reshape(np.swapaxes(IVTgefs[:,:,latind,lonind],1,2),[np.swapaxes(IVTgefs[:,:,latind,lonind],1,2).shape[0]*np.swapaxes(IVTgefs[:,:,latind,lonind],1,2).shape[1],21])
# IVTm_gefs = np.ndarray.flatten(IVTm_gefs[:,latind,lonind])
# IVTgefs = IVTgefs[:,:,latind,lonind]
# Out:
# We are here: /glade/work/wchapman/AnEn/CNN/Coastal_Points_LogNormal
# /glade/scratch/wchapman/GEFS/F048/WY_2016_GEFS_F048.nc
# /glade/scratch/wchapman/GEFS/F048/WY_2017_GEFS_F048.nc
# /glade/scratch/wchapman/GEFS/F048/WY_2018_GEFS_F048.nc
# #################################################
# training: ['/glade/scratch/wchapman/GEFS/F048/WY_2017_GEFS_F048.nc', '/glade/scratch/wchapman/GEFS/F048/WY_2018_GEFS_F048.nc']
# validating: ['/glade/scratch/wchapman/GEFS/F048/WY_2016_GEFS_F048.nc']
# #################################################
# Training IVT shape: (237, 61, 25)
# ...Gathering Training...
# #################################################
# training: ['/glade/scratch/wchapman/GEFS/F048/WY_2016_GEFS_F048.nc', '/glade/scratch/wchapman/GEFS/F048/WY_2018_GEFS_F048.nc']
# validating: ['/glade/scratch/wchapman/GEFS/F048/WY_2017_GEFS_F048.nc']
# #################################################
# Training IVT shape: (236, 61, 25)
# ...Gathering Training...
# #################################################
# training: ['/glade/scratch/wchapman/GEFS/F048/WY_2016_GEFS_F048.nc', '/glade/scratch/wchapman/GEFS/F048/WY_2017_GEFS_F048.nc']
# validating: ['/glade/scratch/wchapman/GEFS/F048/WY_2018_GEFS_F048.nc']
# #################################################
# Training IVT shape: (241, 61, 25)
# ...Gathering Training...

# %%
_set = []
_transformed_set = []
 
num_ense=200
for ii in range(IVTm_pp_gefs.shape[0]):
    texpp = cdf_of_normal(IVTm_pp_gefs[ii],IVT_ppm_gefs[ii],np.sqrt(IVT_ppv_gefs[ii]))
    _transformed_set.append(texpp)

plt.figure(num=None, figsize=(20, 12), dpi=80, facecolor='w', edgecolor='k')
plt.hist(_transformed_set,density=True,bins=16,alpha=0.4,label='GEFS_pp',color='k')
plt.plot()
plt.plot([-10,80],[1,1],'k--')
plt.plot(gefsPIT[1][1:]-(gefsPIT[1][1]-gefsPIT[1][0])/2,gefsPIT[0],'ks',markersize=20,label='GEFS_Raw')
plt.legend(fontsize=26)
plt.ylim([0,3])
plt.xlim([0,1])
plt.xticks(fontsize=19)
plt.yticks(fontsize=19)

plt.show()

# %% [markdown]
# ## What's the Total Binned Spread Skill:

# %%
print(rmse(np.expand_dims(m,axis=1),y_tst))
print(rmse(np.expand_dims(WWRF,axis=1),y_tst))
print(crmse(np.expand_dims(m,axis=1),y_tst))
print(crmse(np.expand_dims(WWRF,axis=1),y_tst))
# Out:
# 45.618907049112735
# 48.11040715151401
# 45.572590247978326
# 47.8142790469515

# %%
plt.plot(m[0:700])
plt.plot(y_tst[0:700])

# %%
plt.hist(np.log(WWRF),60)
plt.show()

# %%
plt.figure(figsize=[15,10])  # inches
plt.hist(np.log(y_tst),60,alpha=0.7,label='ytst',density=True)
plt.hist(np.log(WWRF),60,alpha=0.7,label='wrf',density=True)
plt.hist(np.log(m),60,alpha=0.7,label='model',density=True)
plt.legend(fontsize=22)
plt.show()

# %%
import properscoring as ps
distPPT = (np.squeeze(sAl))
print('...binned spread skill...')
[avgvar_mT,msebin_mT,avgvar_sT,msebin_sT]=spreadskill(mAl,yAl,distPPT,numbins)
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/Spread_Skill_CRPS.npz',mAl=mAl,yAl=yAl,distPPT=distPPT,
#                     numbins=numbins,avgvar_mA=avgvar_mA,msebin_mA=msebin_mA,avgvar_sA=avgvar_sA,msebin_sA=msebin_sA)

crps_ense = ps.crps_ensemble(np.squeeze(yAl[yAl>250]),sssAl[np.squeeze([yAl>250][0][:]),:])
# np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/F036/twCRPS_CRPS.npz',yAl=yAl,sssAl=sssAl,crps_ense=crps_ense)
# Out:
# ...binned spread skill...

# %%
boosty=1000
percy = 0.1

import random

boot_crps=np.zeros([boosty])
for pp in range(boosty):
    toint = random.sample(range(0, len(crps_ense)), int(len(crps_ense)*percy))
    boot_crps[pp] = np.mean(crps_ense[toint])
    
print(np.mean(boot_crps))
ax = sns.boxplot(boot_crps)
# Out:
# 58.12024025080255

# %%
FCN = np.load('/glade/scratch/wchapman/Reforecast/models/NN_FCN/F036/twCRPS_FCN.npz')
crps_ense_fcn = FCN['crps_ense']

boosty=1000
percy = 0.1

import random

boot_crps_fcn=np.zeros([boosty])
for pp in range(boosty):
    toint = random.sample(range(0, len(crps_ense_fcn)), int(len(crps_ense_fcn)*percy))
    boot_crps_fcn[pp] = np.mean(crps_ense_fcn[toint])
    
print(np.mean(boot_crps_fcn))  
ax = sns.boxplot(boot_crps_fcn)
# Out:
# 60.747659012085215

# %%
ale['yAl'].shape
# Out:
# (3416446,)

# %%
np.unique(ale['yAl']).shape
# Out:
# (2613573,)

# %%
ale = np.load('/glade/scratch/wchapman/Reforecast/models/NN_Aleatoric/F036/twCRPS_Aleatoric.npz')
crps_ense_ale = ale['crps_ense']

boosty=1000
percy = 0.1

import random

boot_crps_ale=np.zeros([boosty])
for pp in range(boosty):
    toint = random.sample(range(0, len(crps_ense_ale)), int(len(crps_ense_ale)*percy))
    boot_crps_ale[pp] = np.mean(crps_ense_ale[toint])
    
print(np.mean(boot_crps_ale))  
ax = sns.boxplot(boot_crps_ale)
# Out:
# 58.43728857197058

# %%
pdcrps = pd.DataFrame({'NN_CRPS':boot_crps,'NN_FCN':boot_crps_fcn,'NN_LL':boot_crps_ale})
sns.boxplot(x="variable", y="value", data=pd.melt(pdcrps))
plt.show()

# %%
plt.figure(figsize=[15,10])  # inches
mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()


evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]

# Plotting what I actually want
Z=np.arange(1987,2017,1).tolist()
count=0
for ad,bd,cd,dd,ed in zip(avgvar_mA,msebin_mA,avgvar_sA,msebin_sA,Z):
    # setting rgb color based on z normalized to my range
    plt.errorbar(ad, bd, xerr=3*cd, yerr=3*dd, uplims=True, lolims=True,linewidth=2,color=colors[count],alpha=0.4)
    
    count+=1


    
plt.errorbar(avgvar_mT, msebin_mT, xerr=3*avgvar_sT, yerr=3*msebin_sT, uplims=True, lolims=True,linewidth=4,color='k',alpha=1,label='Full Dataset')
plt.legend(fontsize=20)
plt.plot([0,180],[0,180],linestyle='--',linewidth=3,color=[0.5,0.5,0.5])

plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('Boost Spread Skill Plot',fontsize=25)
cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
cb.ax.tick_params(labelsize=20) 
plt.xlim([0,180])
plt.ylim([0,180])

plt.show()

# %%
plt.figure(figsize=[15,10])  # inches
mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()


evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]

plt.errorbar(avgvar_mT, msebin_mT, xerr=3*avgvar_sT, yerr=3*msebin_sT, uplims=True, lolims=True,linewidth=4,color='k',alpha=1,label='CRPS')
plt.legend(fontsize=20)
plt.plot([0,180],[0,180],linestyle='--',linewidth=3,color=[0.5,0.5,0.5])

plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('CRPS Spread Skill Plot',fontsize=25)
cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
cb.ax.tick_params(labelsize=20) 
plt.xlim([0,180])
plt.ylim([0,180])

plt.show()

# %% [markdown]
# ## Is this trend true?

# %%
All_file_names
numbins = 20
allinds = np.arange(len(All_file_names))

mlAg =dict()
mlAt =dict()
mlAe =dict()
msebin_mA = np.zeros([len(All_file_names),numbins])
msebin_sA = np.zeros([len(All_file_names),numbins])

for bb in range(0,len(All_file_names)):
    allinds = np.arange(len(All_file_names))
#     test_fil_name = [All_file_names[allinds[bb+1]]]
    val_fil_name = [All_file_names[allinds[bb]]]
    
    rest = np.delete(allinds,[bb])
    train_fil_name = np.array(All_file_names)[rest].tolist()
    
    print('#################################################')
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    
    aa = utilsProbSS.deep_learning_generator_ss_mv(val_fil_name, num_samps_val*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]

    rmind = np.where(utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)==0)
    print('before shape test:',y_tst.shape)
    print('deleting test:',rmind[0].shape,'indices')
    x_tst = np.delete(x_tst,rmind[0],0)
    y_tst = np.delete(y_tst,rmind[0],0)
    print('after shape tst:',y_tst.shape)
    
    y_tst = (utilsProbSS.denormalize_images_targ(y_tst,'IVTm',norm_dict_targ))
    x_tst = (utilsProbSS.denormalize_images_targ(x_tst,'IVT',norm_dict))
    [msebin_m,msebin_s,mlt,mlg,mle]=stnd_error_mean(x_tst[:,0],y_tst,numbins)
    msebin_mA[bb,:] = np.squeeze(msebin_m)
    msebin_sA[bb,:] = np.squeeze(msebin_s)
    
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    mlAt[valyr] = mlt
    mlAg[valyr] = mlg
    mlAe[valyr] = mle
# Out:
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/test/F036_WY_2018_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/test/F036_WY_2018_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/test/F036_WY_2018_500mb.nc"...
# before shape test: (103320, 1)
# deleting test: (0,) indices
# after shape tst: (103320, 1)
# ...getting max...

# %%
plt.figure(figsize=[15,10])  # inches

mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()

evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]

# Plotting what I actually want
Z=np.arange(1987,2017,1).tolist()
count=0
for ad,bd,cd in zip(msebin_mA,msebin_sA,Z):
    # setting rgb color based on z normalized to my range
    plt.errorbar(np.arange(0,20),ad,yerr=bd, uplims=True, lolims=True,linewidth=2,color=colors[count],alpha=0.9)
#     plt.plot([0,140],[0,140],'k--')
    count+=1

    
plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned by Max Error',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('Standard Error of the Mean by Year',fontsize=25)
cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
cb.ax.tick_params(labelsize=20) 
plt.xlim([10,20])
plt.show()

# %%
data_to_plot=[mlAt['1985'],mlAt['1986'],mlAt['1987'],mlAt['1988'],mlAt['1989'],mlAt['1990'],
              mlAt['1991'],mlAt['1992'],mlAt['1993'],mlAt['1994'],
             mlAt['1995'],mlAt['1996'],mlAt['1997'],mlAt['1998'],
             mlAt['1999'],mlAt['2000'],mlAt['2001'],mlAt['2002'],
             mlAt['2003'],mlAt['2004'],mlAt['2005'],mlAt['2006'],
             mlAt['2007'],mlAt['2008'],mlAt['2009'],mlAt['2010'],
             mlAt['2011'],mlAt['2012'],mlAt['2013'],mlAt['2014'],
             mlAt['2015'],mlAt['2016'],mlAt['2017'],mlAt['2018']]


fig = plt.figure(1, figsize=(20, 6))

# Create an axes instance
ax = fig.add_subplot(111)
## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='k', linewidth=2)
    # change fill color
    box.set( facecolor = [0.7,0.72,0.7] )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='k', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='k', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='k', linewidth=3)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='k', alpha=0.5)
    
plt.ylim([0,1400])
ax.set_xticklabels(mlAt.keys(),fontsize=20, rotation='vertical')
# ax.set_yticklabels(np.arange(0,1000,0.5),fontsize=20)


ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.title('DJFM by year IVT error of top 7%',fontsize=30)
plt.ylabel('$kg \:  m^{-1} \: s^{-1}$',fontsize=30)

# fname = '/Users/will/Desktop/Haupt/CRPS_MJO_Center.png'
# plt.savefig(fname, dpi=300, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches='tight', pad_inches=0.1,
#         frameon=None, metadata=None)
plt.show()

# %%
data_to_plot=[mlAg['1985'],mlAg['1986'],mlAg['1987'],mlAg['1988'],mlAg['1989'],mlAg['1990'],
              mlAg['1991'],mlAg['1992'],mlAg['1993'],mlAg['1994'],
             mlAg['1995'],mlAg['1996'],mlAg['1997'],mlAg['1998'],
             mlAg['1999'],mlAg['2000'],mlAg['2001'],mlAg['2002'],
             mlAg['2003'],mlAg['2004'],mlAg['2005'],mlAg['2006'],
             mlAg['2007'],mlAg['2008'],mlAg['2009'],mlAg['2010'],
             mlAg['2011'],mlAg['2012'],mlAg['2013'],mlAg['2014'],
             mlAg['2015'],mlAg['2016'],mlAg['2017'],mlAg['2018']]


fig = plt.figure(1, figsize=(20, 6))

# Create an axes instance
ax = fig.add_subplot(111)
## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='k', linewidth=2)
    # change fill color
    box.set( facecolor = [0.7,0.72,0.7] )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='k', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='k', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='k', linewidth=3)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='k', alpha=0.5)
    
plt.ylim([0,1400])
ax.set_xticklabels(mlAg.keys(),fontsize=20, rotation='vertical')
# ax.set_yticklabels(np.arange(0,1000,0.5),fontsize=20)


ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.title('DJFM by year IVT error of top 7%',fontsize=30)
plt.ylabel('$kg \:  m^{-1} \: s^{-1}$',fontsize=30)

# fname = '/Users/will/Desktop/Haupt/CRPS_MJO_Center.png'
# plt.savefig(fname, dpi=300, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches='tight', pad_inches=0.1,
#         frameon=None, metadata=None)
plt.show()

# %%
data_to_plot=[mlAe['1985'],mlAe['1986'],mlAe['1987'],mlAe['1988'],mlAe['1989'],mlAe['1990'],
              mlAe['1991'],mlAe['1992'],mlAe['1993'],mlAe['1994'],
             mlAe['1995'],mlAe['1996'],mlAe['1997'],mlAe['1998'],
             mlAe['1999'],mlAe['2000'],mlAe['2001'],mlAe['2002'],
             mlAe['2003'],mlAe['2004'],mlAe['2005'],mlAe['2006'],
             mlAe['2007'],mlAe['2008'],mlAe['2009'],mlAe['2010'],
             mlAe['2011'],mlAe['2012'],mlAe['2013'],mlAe['2014'],
             mlAe['2015'],mlAe['2016'],mlAe['2017'],mlAe['2018']]


fig = plt.figure(1, figsize=(20, 6))

# Create an axes instance
ax = fig.add_subplot(111)
## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True,showfliers=False)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='k', linewidth=2)
    # change fill color
    box.set( facecolor = [0.7,0.72,0.7] )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='k', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='k', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='k', linewidth=3)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='k', alpha=0.5)
    
plt.ylim([80,380])
ax.set_xticklabels(mlAg.keys(),fontsize=20, rotation='vertical')
# ax.yticklabels(fontsize=20)


ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.title('DJFM by year IVT error of top 5%',fontsize=30)
plt.ylabel('kg m$^{-1}$ s$^{-1}$',fontsize=30)
plt.yticks(fontsize=20)
# fname = '/Users/will/Desktop/Haupt/CRPS_MJO_Center.png'
# plt.savefig(fname, dpi=300, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches='tight', pad_inches=0.1,
#         frameon=None, metadata=None)
plt.show()

# %% [markdown]
# ## There is clearly a trend in the model skill....even though this is a reforecast.
#
# if we had a date vector... maybe this will help? This generator gives the forecast time, and an index which ranges a linear trend from -2 to 2 for 1985-->2018

# %%
aa = utilsProbSS.deep_learning_generator_ss_mv_time(train_fil_name, num_samps_train*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
adf = next(aa)
x = adf[0]
y = adf[1]
timy = adf[2]
timy_ind = adf[3]

# %%
len(All_file_names)
# Out:
# 34

# %%
All_file_names
boostnum = 500 #boost IVT overs this number. 

allinds = np.arange(len(All_file_names))

for bb in range(32,len(All_file_names)-1):
    allinds = np.arange(len(All_file_names))
    test_fil_name = [All_file_names[allinds[bb+1]]]
    val_fil_name = [All_file_names[allinds[bb]]]
    
    rest = np.delete(allinds,[bb,bb+1])
    train_fil_name = np.array(All_file_names)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utilsProbSS.deep_learning_generator_ss_mv_time(train_fil_name, num_samps_train*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
    adf = next(aa)
    x = adf[0]
    y = adf[1]
    train_tim=adf[2]
    train_timind=adf[3]
    aa = utilsProbSS.deep_learning_generator_ss_mv_time(val_fil_name, num_samps_val*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]
    tst_tim=adf[2]
    tst_timind=adf[3]

    #remove x and y where x ==0 
    rmind = np.where(utilsProbSS.denormalize_images_targ(x[:,0],'IVT',norm_dict)==0)
    print('before shape:',y.shape)
    print('deleting:',rmind[0].shape,'indices')
    x = np.delete(x,rmind[0],0)
    y = np.delete(y,rmind[0],0)
    print('after shape:',y.shape)
    
    rmind = np.where(utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)==0)
    print('before shape test:',y_tst.shape)
    print('deleting test:',rmind[0].shape,'indices')
    x_tst = np.delete(x_tst,rmind[0],0)
    y_tst = np.delete(y_tst,rmind[0],0)
    print('after shape tst:',y_tst.shape)       
    
    
    print('y_tst:',y_tst.shape[0])
    print('x_tst:',x_tst.shape[0])
    
    print('...Encoding Stations...')

    SUMID = np.unique(x[:,6]+x[:,7])
    #station ID integers 
    stID = np.zeros([x.shape[0],1])
    for jj,un in enumerate(SUMID):
        mats = np.where(x[:,6]+x[:,7]==un)
        stID[mats,:] = int(jj)
    stID=stID.astype(int)

    #station ID integers 
    stID_tst = np.zeros([x_tst.shape[0],1])
    for jj,un in enumerate(SUMID):
        mats = np.where(x_tst[:,6]+x_tst[:,7]==un)
        stID_tst[mats,:] = int(jj)
    stID_tst=stID_tst.astype(int)
    print('...done...')

    
    x=x[:,:6]
    x_tst=x_tst[:,:6]
    
    #append a date vector. 
    x = np.concatenate((x,train_timind),axis=1)
    x_tst = np.concatenate((x_tst,tst_timind),axis=1)
    
    ### Model Build #### 
    
    in_shape = x.shape[1]
    print('In shape: ',in_shape)
    out_shape = 1
    print('Out shape: ',out_shape)
    
    max_id = np.max(stID)
    model = build_emb_model(in_shape,out_shape,2,max_id ,compile=True)
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
    Wsave_name = '/glade/scratch/wchapman/Reforecast/models/NN_Bayes/' +fcast+'/cpf_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
    print(Wsave_name)
    
    modsave = tf.keras.callbacks.ModelCheckpoint(Wsave_name, monitor='val_loss', verbose=1, save_best_only=True,save_weights_only=True, mode='min',include_optimizer=False)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.4,patience=2, min_lr=0.00001,verbose=1)
    er_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto',baseline=None, restore_best_weights=False)
    net_in = tf.keras.layers.Input(shape=(in_shape))
    
    #train model
    histss = model.fit([x,stID], y,validation_data=([x_tst,stID_tst],y_tst), epochs=20,batch_size=100 ,verbose=True,callbacks=[modsave,reduce_lr,er_stop]);
    
    hist_df = pd.DataFrame(histss.history) 

   
    # or save to csv: 
    hist_csv_file = '/glade/work/wchapman/AnEn/CNN/Reforecast/fithist_'+ valyr+'_test_'+tstyr+'.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
        
    break
# Out:
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F036/test/F036_WY_2018_500mb.nc']
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# before shape: (3263104, 1)
# deleting: (0,) indices
# after shape: (3263104, 1)
# before shape test: (101760, 1)
# deleting test: (0,) indices
# after shape tst: (101760, 1)
# y_tst: 101760
# x_tst: 101760
# ...Encoding Stations...
# ...done...
# In shape:  7
# Out shape:  1
# Model: "model_34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_71 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_34 (Embedding)        (None, 1, 2)         1696        input_71[0][0]
# __________________________________________________________________________________________________
# input_70 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 2)            0           embedding_34[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 9)            0           input_70[0][0]
#                                                                  flatten_34[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 40)           400         concatenate_34[0][0]
# __________________________________________________________________________________________________
# DV1 (DenseVariational)          (None, 30)           3690        dense_68[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 2)            62          DV1[0][0]
# __________________________________________________________________________________________________
# distribution_lambda_34 (Distrib ((None, 1), (None, 1 0           dense_69[0][0]
# ==================================================================================================
# Total params: 5,848
# Trainable params: 5,848
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# Train on 3263104 samples, validate on 101760 samples
# Epoch 1/20
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 657.9322
# Epoch 00001: val_loss improved from inf to 3.11049, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 104s 32us/sample - loss: 657.8912 - val_loss: 3.1105
# Epoch 2/20
# 3262100/3263104 [============================>.] - ETA: 0s - loss: 1.3856
# Epoch 00002: val_loss improved from 3.11049 to 0.24983, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 88s 27us/sample - loss: 1.3853 - val_loss: 0.2498
# Epoch 3/20
# 3262500/3263104 [============================>.] - ETA: 0s - loss: 0.2527
# Epoch 00003: val_loss improved from 0.24983 to 0.03106, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 97s 30us/sample - loss: 0.2527 - val_loss: 0.0311
# Epoch 4/20
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 0.1870
# Epoch 00004: val_loss improved from 0.03106 to 0.01469, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 95s 29us/sample - loss: 0.1870 - val_loss: 0.0147
# Epoch 5/20
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 0.1663
# Epoch 00005: val_loss improved from 0.01469 to -0.01005, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 86s 26us/sample - loss: 0.1663 - val_loss: -0.0101
# Epoch 6/20
# 3262500/3263104 [============================>.] - ETA: 0s - loss: 0.1560
# Epoch 00006: val_loss improved from -0.01005 to -0.01070, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 98s 30us/sample - loss: 0.1560 - val_loss: -0.0107
# Epoch 7/20
# 3262600/3263104 [============================>.] - ETA: 0s - loss: 0.1484
# Epoch 00007: val_loss improved from -0.01070 to -0.01775, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 90s 28us/sample - loss: 0.1484 - val_loss: -0.0177
# Epoch 8/20
# 3261900/3263104 [============================>.] - ETA: 0s - loss: 0.1439
# Epoch 00008: val_loss improved from -0.01775 to -0.01944, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 93s 29us/sample - loss: 0.1439 - val_loss: -0.0194
# Epoch 9/20
# 3263100/3263104 [============================>.] - ETA: 0s - loss: 0.1400
# Epoch 00009: val_loss improved from -0.01944 to -0.02428, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 95s 29us/sample - loss: 0.1400 - val_loss: -0.0243
# Epoch 10/20
# 3261900/3263104 [============================>.] - ETA: 0s - loss: 0.1370
# Epoch 00010: val_loss improved from -0.02428 to -0.03124, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 88s 27us/sample - loss: 0.1371 - val_loss: -0.0312
# Epoch 11/20
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 0.1342
# Epoch 00011: val_loss did not improve from -0.03124
# 3263104/3263104 [==============================] - 102s 31us/sample - loss: 0.1342 - val_loss: -0.0276
# Epoch 12/20
# 3263000/3263104 [============================>.] - ETA: 0s - loss: 0.1317
# Epoch 00012: val_loss improved from -0.03124 to -0.03273, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 98s 30us/sample - loss: 0.1317 - val_loss: -0.0327
# Epoch 13/20
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 0.1301
# Epoch 00013: val_loss improved from -0.03273 to -0.04574, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 97s 30us/sample - loss: 0.1302 - val_loss: -0.0457
# Epoch 14/20
# 3263000/3263104 [============================>.] - ETA: 0s - loss: 0.1280
# Epoch 00014: val_loss did not improve from -0.04574
# 3263104/3263104 [==============================] - 97s 30us/sample - loss: 0.1280 - val_loss: -0.0398
# Epoch 15/20
# 3262000/3263104 [============================>.] - ETA: 0s - loss: 0.1264
# Epoch 00015: val_loss did not improve from -0.04574
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 3263104/3263104 [==============================] - 93s 29us/sample - loss: 0.1264 - val_loss: -0.0359
# Epoch 16/20
# 3262500/3263104 [============================>.] - ETA: 0s - loss: 0.1236
# Epoch 00016: val_loss improved from -0.04574 to -0.04912, saving model to /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# 3263104/3263104 [==============================] - 106s 33us/sample - loss: 0.1236 - val_loss: -0.0491
# Epoch 17/20
# 3263000/3263104 [============================>.] - ETA: 0s - loss: 0.1228
# Epoch 00017: val_loss did not improve from -0.04912
# 3263104/3263104 [==============================] - 109s 33us/sample - loss: 0.1228 - val_loss: -0.0461
# Epoch 18/20
# 3262900/3263104 [============================>.] - ETA: 0s - loss: 0.1219
# Epoch 00018: val_loss did not improve from -0.04912
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.5999999595806004e-05.
# 3263104/3263104 [==============================] - 103s 32us/sample - loss: 0.1219 - val_loss: -0.0485
# Epoch 19/20
# 3262600/3263104 [============================>.] - ETA: 0s - loss: 0.1211
# Epoch 00019: val_loss did not improve from -0.04912
# 3263104/3263104 [==============================] - 114s 35us/sample - loss: 0.1211 - val_loss: -0.0488
# Epoch 20/20
# 3261500/3263104 [============================>.] - ETA: 0s - loss: 0.1208
# Epoch 00020: val_loss did not improve from -0.04912
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# 3263104/3263104 [==============================] - 106s 32us/sample - loss: 0.1208 - val_loss: -0.0460

# %% [markdown]
# ##### This generator gives you the time vector as a string and also characterizes the time as a number betweeen -2 and 2 from 1985 --> 2018

# %%
All_file_names
ense = 200
numbins = 15
allinds = np.arange(len(All_file_names))


avgvar_mA = np.zeros([len(All_file_names)-1,numbins])
msebin_mA = np.zeros([len(All_file_names)-1,numbins])
avgvar_sA = np.zeros([len(All_file_names)-1,numbins])
msebin_sA = np.zeros([len(All_file_names)-1,numbins])

mAl =np.array([])
sAl =np.array([])
yAl =np.array([])

for ddfa, bb in enumerate(range(32,len(All_file_names)-1)):
    allinds = np.arange(len(All_file_names))
    test_fil_name = [All_file_names[allinds[bb+1]]]
    val_fil_name = [All_file_names[allinds[bb]]]
    
    rest = np.delete(allinds,[bb,bb+1])
    train_fil_name = np.array(All_file_names)[rest].tolist()
    
    print('#################################################')
    print('testing:',test_fil_name)
    print('validating:',val_fil_name)
    print('#################################################')
    
    num_samps_train = utilsProb.count_samps(train_fil_name)
    num_samps_val = utilsProb.count_samps(val_fil_name)

    print('...gathering data...')
    aa = utilsProbSS.deep_learning_generator_ss_mv_time(train_fil_name, num_samps_train*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
    adf = next(aa)
    x = adf[0]
    y = adf[1]
    train_tim=adf[2]
    train_timind=adf[3]
    aa = utilsProbSS.deep_learning_generator_ss_mv_time(val_fil_name, num_samps_val*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
    adf = next(aa)
    x_tst = adf[0]
    y_tst = adf[1]
    tst_tim=adf[2]
    tst_timind=adf[3]

    #remove x and y where x ==0 
    rmind = np.where(utilsProbSS.denormalize_images_targ(x[:,0],'IVT',norm_dict)==0)
    print('before shape:',y.shape)
    print('deleting:',rmind[0].shape,'indices')
    x = np.delete(x,rmind[0],0)
    y = np.delete(y,rmind[0],0)
    print('after shape:',y.shape)
    
    rmind = np.where(utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)==0)
    print('before shape test:',y_tst.shape)
    print('deleting test:',rmind[0].shape,'indices')
    x_tst = np.delete(x_tst,rmind[0],0)
    y_tst = np.delete(y_tst,rmind[0],0)
    print('after shape tst:',y_tst.shape)       
    
    
    print('y_tst:',y_tst.shape[0])
    print('x_tst:',x_tst.shape[0])
    
    print('...Encoding Stations...')

    SUMID = np.unique(x[:,6]+x[:,7])
    #station ID integers 
    stID = np.zeros([x.shape[0],1])
    for jj,un in enumerate(SUMID):
        mats = np.where(x[:,6]+x[:,7]==un)
        stID[mats,:] = int(jj)
    stID=stID.astype(int)

    #station ID integers 
    stID_tst = np.zeros([x_tst.shape[0],1])
    for jj,un in enumerate(SUMID):
        mats = np.where(x_tst[:,6]+x_tst[:,7]==un)
        stID_tst[mats,:] = int(jj)
    stID_tst=stID_tst.astype(int)
    print('...done...')

    
    x=x[:,:6]
    x_tst=x_tst[:,:6]
    
    #append a date vector. 
    x = np.concatenate((x,train_timind),axis=1)
    x_tst = np.concatenate((x_tst,tst_timind),axis=1)
    
    ### Model Build #### 
    
    in_shape = x.shape[1]
    print('In shape: ',in_shape)
    out_shape = 1
    print('Out shape: ',out_shape)
    
    max_id = np.max(stID)
    model = build_emb_model(in_shape,out_shape,2,max_id ,compile=True)
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    
    tstyr= test_fil_name[0].split('_500mb')[0]
    tstyr =tstyr.split('_')[2]
    Wsave_name = '/glade/scratch/wchapman/Reforecast/models/NN_Bayes/' +fcast+'/cpf_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    print("... loading....",Wsave_name)
    
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    model.load_weights(Wsave_name)
    ### CHANGE THIS FOR PRODUCTION RUNS ###########
    
    yhat = model([x_tst,stID_tst])

    m = np.zeros([x_tst.shape[0],1])
    for pp in range(ense):
        m += yhat.mean().numpy()
    m = m/ense

    m = (utilsProbSS.denormalize_images_targ(m,'IVT',norm_dict))

    s = np.zeros([x_tst.shape[0],1])
    for pp in range(ense):
        s += yhat.stddev().numpy()
    s = s/ense

    mm = np.zeros([x_tst.shape[0],1])
    for pp in range(ense):
        mm += yhat.mean().numpy()
    mm = mm/ense
    
    if ddfa >=20:
        print('scaled')
        ssu = (utilsProbSS.denormalize_images_targ(mm,'IVT',norm_dict)+(s*norm_dict['IVT'][1]))
        ssd = (utilsProbSS.denormalize_images_targ(mm,'IVT',norm_dict)-(s*norm_dict['IVT'][1]))
    else: 
        ssu = (utilsProbSS.denormalize_images_targ(mm,'IVT',norm_dict)+(s*norm_dict['IVT'][1]))
        ssd = (utilsProbSS.denormalize_images_targ(mm,'IVT',norm_dict)-(s*norm_dict['IVT'][1]))
    y_tst = (utilsProbSS.denormalize_images_targ(y_tst,'IVTm',norm_dict_targ))
    WWRF = utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)
    distPP = (np.squeeze(ssu) - np.squeeze(m))
    
    
    mAl = np.append(mAl,np.ndarray.flatten(m))
    yAl = np.append(yAl,np.ndarray.flatten(y_tst))
    sAl = np.append(sAl,np.ndarray.flatten(ssu))
    
    print('...binned spread skill...')
    [avgvar_m,msebin_m,avgvar_s,msebin_s]=spreadskill(m,y_tst,distPP,numbins)
    
    avgvar_mA[bb,:] = np.squeeze(avgvar_m)
    msebin_mA[bb,:] = np.squeeze(msebin_m)
    avgvar_sA[bb,:] = np.squeeze(avgvar_s)
    msebin_sA[bb,:] = np.squeeze(msebin_s)
    
    plt.figure(figsize=[15,10])  # inches
    plt.errorbar(avgvar_m, (msebin_m), xerr=avgvar_s, yerr=msebin_s, uplims=True, lolims=True,color='r',linewidth=2)
    plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
    plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

    plt.tick_params(axis='x', labelsize=15)
    plt.tick_params(axis='y', labelsize=15)
    plt.title('Spread Skill Plot',fontsize=25)

    plt.plot([0,180],[0,180],'k--')
    plt.show()
    
    print(rmse(m,y_tst))
    print(rmse(np.expand_dims(WWRF,axis=1),y_tst))
    print(crmse(m,y_tst))
    print(crmse(np.expand_dims(WWRF,axis=1),y_tst))
    print(bias(m,y_tst))
    print(bias(np.expand_dims(WWRF,axis=1),y_tst))
# Out:
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F036/test/F036_WY_2018_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F036/validate/F036_WY_2017_500mb.nc"...
# before shape: (3263104, 1)
# deleting: (0,) indices
# after shape: (3263104, 1)
# before shape test: (101760, 1)
# deleting test: (0,) indices
# after shape tst: (101760, 1)
# y_tst: 101760
# x_tst: 101760
# ...Encoding Stations...
# ...done...
# In shape:  7
# Out shape:  1
# Model: "model_36"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_76 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 1, 2)         1696        input_76[0][0]
# __________________________________________________________________________________________________
# input_75 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_36 (Flatten)            (None, 2)            0           embedding_36[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 9)            0           input_75[0][0]
#                                                                  flatten_36[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 40)           400         concatenate_36[0][0]
# __________________________________________________________________________________________________
# DV1 (DenseVariational)          (None, 30)           3690        dense_72[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 2)            62          DV1[0][0]
# __________________________________________________________________________________________________
# distribution_lambda_36 (Distrib ((None, 1), (None, 1 0           dense_73[0][0]
# ==================================================================================================
# Total params: 5,848
# Trainable params: 5,848
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ... loading.... /glade/scratch/wchapman/Reforecast/models/NN_Bayes/F036/cpf_val_2017_test_2018.ckpt
# ...binned spread skill...
# 49.950377194909464
# 51.08285165121412
# 49.234491326527696
# 50.88791473630188
# 8.426460976828992
# 4.458542

# %%
x_tst.shape
# Out:
# (101760, 7)

# %% [markdown]
# ## How about the whole domain?

# %%
jago['predictor_matrix'].shape
# Out:
# (120, 848, 8)

# %%
timess.shape
# Out:
# (120,)

# %%
All_file_names
numbins = 20
allinds = np.arange(len(All_file_names))

mlAg =dict()
mlAt =dict()
mlAe =dict()
msebin_mA = np.zeros([len(All_file_names),numbins])
msebin_sA = np.zeros([len(All_file_names),numbins])

for bb in range(0,len(All_file_names)):
    allinds = np.arange(len(All_file_names))
    val_fil_name = [All_file_names[allinds[bb]]]
    
    rest = np.delete(allinds,[bb])
    train_fil_name = np.array(All_file_names)[rest].tolist()
    
    print('#################################################')
    print('validatiing:',val_fil_name)
    print('#################################################')
    
    getIVT = Dataset(val_fil_name[0])
    
    IVT =getIVT['IVT']
    x_tst = np.reshape(IVT,[IVT.shape[0],-1])

    IVTm = getIVT['IVTm']
    y_tst = np.reshape(IVTm,[IVTm.shape[0],-1])
    
    rmind = np.where(IVTm==0)
    print('before shape test:',y_tst.shape)
    print('deleting test:',rmind[0].shape,'indices')
    x_tst = np.delete(x_tst,rmind[0],0)
    y_tst = np.delete(y_tst,rmind[0],0)
    print('after shape tst:',y_tst.shape)
         
    [msebin_m,msebin_s,mlt,mlg,mle]=stnd_error_mean(x_tst,y_tst,numbins)
    msebin_mA[bb,:] = np.squeeze(msebin_m)
    msebin_sA[bb,:] = np.squeeze(msebin_s)
    
    valyr= val_fil_name[0].split('_500mb')[0]
    valyr =valyr.split('_')[2]
    mlAt[valyr] = mlt
    mlAg[valyr] = mlg
    mlAe[valyr] = mle
# Out:
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1985_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1986_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1987_500mb.nc']
# #################################################
# before shape test: (121, 4047)
# deleting test: (0,) indices
# after shape tst: (121, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1988_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1989_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1990_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1991_500mb.nc']
# #################################################
# before shape test: (121, 4047)
# deleting test: (0,) indices
# after shape tst: (121, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1992_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1993_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1994_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1995_500mb.nc']
# #################################################
# before shape test: (121, 4047)
# deleting test: (0,) indices
# after shape tst: (121, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1996_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1997_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1998_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_1999_500mb.nc']
# #################################################
# before shape test: (121, 4047)
# deleting test: (0,) indices
# after shape tst: (121, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2000_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2001_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2002_500mb.nc']
# #################################################
# before shape test: (120, 4047)
# deleting test: (0,) indices
# after shape tst: (120, 4047)
# ...getting max...
# #################################################
# validatiing: ['/glade/scratch/wchapman/Reforecast/F036/train/F036_WY_2003_500mb.nc']
# #################################################
# before shape test: (121, 4047)
# deleting test: (0,) indices
# after shape tst: (121, 4047)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-156f942f0191>", line 37, in <module>
#     [msebin_m,msebin_s,mlt,mlg,mle]=stnd_error_mean(x_tst,y_tst,numbins)
#   File "<ipython-input-5-ccd489cdacd5>", line 206, in stnd_error_mean
#     tmse[ii]  = np.sqrt(np.mean(np.random.choice(err_sort[locbin],len(locbin))))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/posixpath.py", line 428, in _joinrealpath
#     newpath = join(path, name)
#   File "/glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/posixpath.py", line 92, in join
#     path += sep + b
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
plt.figure(figsize=[15,10])  # inches

mymap = cm.RdBu
min, max = (1985, 2018)
step = 1
# to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()

evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
colors = [cm.RdBu(x) for x in evenly_spaced_interval]

# Plotting what I actually want
Z=np.arange(1987,2017,1).tolist()
count=0
for ad,bd,cd in zip(msebin_mA,msebin_sA,Z):
    # setting rgb color based on z normalized to my range
    plt.errorbar(np.arange(0,20),ad,yerr=bd, uplims=True, lolims=True,linewidth=2,color=colors[count],alpha=0.9)
#     plt.plot([0,140],[0,140],'k--')
    count+=1

    
plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
plt.xlabel('Binned by Max Error',fontsize=25)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.title('Standard Error of the Mean by Year',fontsize=25)
cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
cb.ax.tick_params(labelsize=20) 
plt.xlim([0,20])
plt.show()

# %%
data_to_plot=[mlAe['1985'],mlAe['1986'],mlAe['1987'],mlAe['1988'],mlAe['1989'],mlAe['1990'],
              mlAe['1991'],mlAe['1992'],mlAe['1993'],mlAe['1994'],
             mlAe['1995'],mlAe['1996'],mlAe['1997'],mlAe['1998'],
             mlAe['1999'],mlAe['2000'],mlAe['2001'],mlAe['2002'],
             mlAe['2003'],mlAe['2004'],mlAe['2005'],mlAe['2006'],
             mlAe['2007'],mlAe['2008'],mlAe['2009'],mlAe['2010'],
             mlAe['2011'],mlAe['2012'],mlAe['2013'],mlAe['2014'],
             mlAe['2015'],mlAe['2016'],mlAe['2017'],mlAe['2018']]


fig = plt.figure(1, figsize=(20, 6))

# Create an axes instance
ax = fig.add_subplot(111)
## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True,showfliers=False)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='k', linewidth=2)
    # change fill color
    box.set( facecolor = [0.7,0.72,0.7] )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='k', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='k', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='k', linewidth=3)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='k', alpha=0.5)
    
plt.ylim([80,380])
ax.set_xticklabels(mlAg.keys(),fontsize=20, rotation='vertical')
# ax.set_yticklabels(np.arange(0,1000,0.5),fontsize=20)


ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.title('DJFM by year IVT error of top 5%',fontsize=30)
plt.ylabel('$kg \:  m^{-1} \: s^{-1}$',fontsize=30)

plt.plot([0,35],[100,100],'k--')
# fname = '/Users/will/Desktop/Haupt/CRPS_MJO_Center.png'
# plt.savefig(fname, dpi=300, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches='tight', pad_inches=0.1,
#         frameon=None, metadata=None)
plt.show()

# %%
data_to_plot=[mlAt['1987'],mlAt['1988'],mlAt['1989'],mlAt['1990'],
              mlAt['1991'],mlAt['1992'],mlAt['1993'],mlAt['1994'],
             mlAt['1995'],mlAt['1996'],mlAt['1997'],mlAt['1998'],
             mlAt['1999'],mlAt['2000'],mlAt['2001'],mlAt['2002'],
             mlAt['2003'],mlAt['2004'],mlAt['2005'],mlAt['2006'],
             mlAt['2007'],mlAt['2008'],mlAt['2009'],mlAt['2010'],
             mlAt['2011'],mlAt['2012'],mlAt['2013'],mlAt['2014'],
             mlAt['2015'],mlAt['2016'],mlAt['2017']]


fig = plt.figure(1, figsize=(20, 6))

# Create an axes instance
ax = fig.add_subplot(111)
## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='k', linewidth=2)
    # change fill color
    box.set( facecolor = [0.7,0.72,0.7] )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='k', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='k', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='k', linewidth=3)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='k', alpha=0.5)
    
plt.ylim([-20,1500])
ax.set_xticklabels(mlAt.keys(),fontsize=20, rotation='vertical')
# ax.set_yticklabels(np.arange(0,1000,0.5),fontsize=20)


ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.title('DJFM by year IVT error of top 5%',fontsize=30)
plt.ylabel('$kg \:  m^{-1} \: s^{-1}$',fontsize=30)

# fname = '/Users/will/Desktop/Haupt/CRPS_MJO_Center.png'
# plt.savefig(fname, dpi=300, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches='tight', pad_inches=0.1,
#         frameon=None, metadata=None)
plt.show()

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from pprint import pprint
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()
import tensorflow_probability as tfp
from tensorflow.python.keras.optimizer_v2.adam import Adam
tfd = tfp.distributions
import tensorflow.keras.backend as K
from tensorflow import math as tfm

import os

import utilsProb
import utilsProbSS
import glob
import sys
from scipy.stats import rankdata
import pandas as pd
import importlib
import copy
from netCDF4 import Dataset, num2date
from scipy.interpolate import interpn
from matplotlib.colors import Normalize 
from matplotlib import cm
import matplotlib as mpl
import seaborn as sns
sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
import properscoring as ps


os.environ["CUDA_VISIBLE_DEVICES"]="-1"

if tf.test.gpu_device_name() != '/device:GPU:0':
    print('WARNING: GPU device not found.')
else:
    print('SUCCESS: Found GPU: {}'.format(tf.test.gpu_device_name()))


    
negloglik = lambda y, rv_y: -rv_y.log_prob(y)


def rmse(guess,truth):
    n = len(truth)
    rms = np.linalg.norm(guess - truth) / np.sqrt(n)
    return rms


def bias(guess,truth):
    bb = np.mean(guess)-np.mean(truth)
    return bb

def corrss(guess,truth):
    bb = np.corrcoef(np.squeeze(guess),np.squeeze(truth))[0,1]
    return bb


def crmse(guess,truth):
    guess = np.squeeze(guess)
    truth = np.squeeze(truth)
    mg = np.mean(guess)
    mt = np.mean(truth)
    n = len(truth)
    bb=np.linalg.norm((guess-mg) - (truth-mt)) / np.sqrt(n)
    return bb

def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]


def spreadskill(guess,truth,stddevver,numbins):
#     guess: postprocess guess any input shape
#     truth: true value any input shape 
#     stddevver: standard deviation of the guess any input shape
#     returns: 
#         variance mean, mse mean, bootstraped variance, bootrapped mean
    
    distPP = np.ndarray.flatten(stddevver)
    guess = np.ndarray.flatten(guess)
    truth = np.ndarray.flatten(truth)
    
    indexsort = np.argsort(distPP)
    err = (guess- truth)**2
    varianceall = distPP[indexsort]
    err_sort = err[indexsort]

    numbins = numbins 
    inds = np.zeros(len(varianceall))
    numst = 0
    for nn in range(numbins):
        numdo = int(len(varianceall)/numbins)
        inds[numst:numdo*(nn+1)] = nn
    
        if nn ==np.max(range(numbins)):
            inds[numst:] = nn
        numst+=numdo
    
    avgvar_m = []
    msebin_m = []

    avgvar_s = []
    msebin_s = []
    nummy =2000

    for bb in np.unique(inds):
        locbin = np.where([inds==bb])[1]
        tavg =0
        tmse =0
        tavg = np.zeros(nummy)
        tmse = np.zeros(nummy)
        for ii in range(nummy):
            tavg[ii]  = np.mean(np.random.choice(varianceall[locbin],len(locbin)))
            tmse[ii]  = np.sqrt(np.mean(np.random.choice(err_sort[locbin],len(locbin))))
        avgvar_m = np.append(avgvar_m,np.mean(tavg))
        msebin_m = np.append(msebin_m,np.mean(tmse))
        avgvar_s = np.append(avgvar_s,np.std(tavg))
        msebin_s = np.append(msebin_s,np.std(tmse))
    return avgvar_m,msebin_m,avgvar_s,msebin_s

def density_scatter( x , y, ax = None, sort = True, bins = 20, **kwargs )   :
    """
    Scatter plot colored by 2d histogram
    """
    if ax is None :
        fig , ax = plt.subplots(figsize=(10, 8))
    data , x_e, y_e = np.histogram2d( x, y, bins = bins, density = True )
    z = interpn( ( 0.5*(x_e[1:] + x_e[:-1]) , 0.5*(y_e[1:]+y_e[:-1]) ) , data , np.vstack([x,y]).T , method = "splinef2d", bounds_error = False)

    #To be sure to plot all data
    z[np.where(np.isnan(z))] = 0.0

    # Sort the points by density, so that the densest points are plotted last
    if sort :
        idx = z.argsort()
        x, y, z = x[idx], y[idx], z[idx]

    ax.scatter( x, y, c=z, **kwargs )

    norm = Normalize(vmin = np.min(z), vmax = np.max(z))
    cbar = fig.colorbar(cm.ScalarMappable(norm = norm), ax=ax)
    cbar.ax.set_ylabel('Density')

    return ax


def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))
    return tf.keras.Sequential([
      tfp.layers.VariableLayer(2 * n, dtype=dtype,name='banjo'),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t[..., :n],scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
          reinterpreted_batch_ndims=1),name='banjo2'),
  ])


# Specify the prior over `keras.layers.Dense` `kernel` and `bias`.
def prior_trainable(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    return tf.keras.Sequential([
      tfp.layers.VariableLayer(n, dtype=dtype,name='spoon'),
      tfp.layers.DistributionLambda(lambda t: tfd.Independent(
          tfd.Normal(loc=t, scale=1),
          reinterpreted_batch_ndims=1),name='doon'),
  ])



def stnd_error_mean(guess,truth,numbins):
#     guess: postprocess guess any input shape
#     truth: true value any input shape 
#     stddevver: standard deviation of the guess any input shape
#     returns: 
#         variance mean, mse mean, bootstraped variance, bootrapped mean
    
    guess = np.ndarray.flatten(guess)
    truth = np.ndarray.flatten(truth)
    

    err = (guess- truth)**2
    indexsort = np.argsort(err)
    err_sort = err[indexsort]
    
    truthSORT = truth[indexsort]
    guessSORT = guess[indexsort]

    numbins = numbins 
    inds = np.zeros(len(err_sort))
    numst = 0
    for nn in range(numbins):
        numdo = int(len(err_sort)/numbins)
        inds[numst:numdo*(nn+1)] = nn
    
        if nn ==np.max(range(numbins)):
            inds[numst:] = nn
        numst+=numdo
        
    msebin_m = []
    msebin_s = []
    nummy =2000
    maxlist=[]
    for bb in np.unique(inds):
        locbin = np.where([inds==bb])[1]
        tmse =0
        tmse = np.zeros(nummy)
        for ii in range(nummy):
            tmse[ii]  = np.sqrt(np.mean(np.random.choice(err_sort[locbin],len(locbin))))
        msebin_m = np.append(msebin_m,np.mean(tmse))
        msebin_s = np.append(msebin_s,np.std(tmse))
        
        if bb == np.max(np.unique(inds)):
            print('...getting max...')
            mlt = truthSORT[locbin]
            mlg = guessSORT[locbin]
            mle = np.sqrt((truthSORT[locbin]-guessSORT[locbin])**2)
            
        
    return msebin_m,msebin_s,mlt,mlg,mle



def crps_cost_function(y_true, y_pred, theano=False):
    """Compute the CRPS cost function for a normal distribution defined by
    the mean and standard deviation.
    Code inspired by Kai Polsterer (HITS).
    Args:
        y_true: True values
        y_pred: Tensor containing predictions: [mean, std]
        theano: Set to true if using this with pure theano.
    Returns:
        mean_crps: Scalar with mean CRPS over batch
    """

    # Split input
    mu = y_pred[:, 0]
    sigma = y_pred[:, 1]
    # Ugly workaround for different tensor allocation in keras and theano
    if not theano:
        y_true = y_true[:, 0]   # Need to also get rid of axis 1 to match!

    # To stop sigma from becoming negative we first have to 
    # convert it the the variance and then take the square
    # root again. 
    var = K.square(sigma)
    # The following three variables are just for convenience
    loc = (y_true - mu) / K.sqrt(var)
    phi = 1.0 / np.sqrt(2.0 * np.pi) * K.exp(-K.square(loc) / 2.0)
    Phi = 0.5 * (1.0 + tfm.erf(loc / np.sqrt(2.0)))
    # First we will compute the crps for each input/target pair
    crps =  K.sqrt(var) * (loc * (2. * Phi - 1.) + 2 * phi - 1. / np.sqrt(np.pi))
    # Then we take the mean. The cost is now a scalar
    return K.mean(crps)


def build_emb_model(n_features, n_outputs, hidden_nodes, emb_size, max_id,
                    compile=False, optimizer='adam', lr=0.01,
                    loss=crps_cost_function,
                    activation='relu', reg=None):
    """
    Args:
        n_features: Number of features
        n_outputs: Number of outputs
        hidden_nodes: int or list of hidden nodes
        emb_size: Embedding size
        max_id: Max embedding ID
        compile: If true, compile model
        optimizer: Name of optimizer
        lr: learning rate
        loss: loss function
        activation: Activation function for hidden layer
    Returns:
        model: Keras model
    """
    if type(hidden_nodes) is not list:
        hidden_nodes = [hidden_nodes]

    features_in = tf.keras.layers.Input(shape=(n_features,))
    id_in = tf.keras.layers.Input(shape=(1,))
    emb = tf.keras.layers.Embedding(max_id + 1, emb_size)(id_in)
    emb = tf.keras.layers.Flatten()(emb)
    x = tf.keras.layers.Concatenate()([features_in, emb])
    for h in hidden_nodes:
        x = tf.keras.layers.Dense(h, activation=activation, kernel_regularizer=reg)(x)
    x = tf.keras.layers.Dense(n_outputs, activation='linear', kernel_regularizer=reg)(x)
    model = tf.keras.models.Model(inputs=[features_in, id_in], outputs=x)

    if compile:
        opt = tf.optimizers.Adam(learning_rate=lr)
        model.compile(optimizer=opt, loss=loss)
    return model

def lognstat(mu, sigma):
    """Calculate the mean of and variance of the lognormal distribution given
    the mean (`mu`) and standard deviation (`sigma`), of the associated normal 
    distribution."""
    m = np.exp(mu + sigma**2 / 2.0)
    v = np.exp(2 * mu + sigma**2) * (np.exp(sigma**2) - 1)
    return m, v



for stepnum in range(1,10):
    tf.keras.backend.clear_session()
    print(stepnum)
    dd = '/glade/scratch/wchapman/Reforecast/'
    os.chdir(dd)
    yago= next(os.walk('.'))[1]
    yago = sorted(yago)
    subs = 'F'
    res = [ii for ii in yago if subs in ii] 
    res

    for fcast in res[:stepnum]: 
        os.chdir(dd+'/'+fcast)
        print(os.getcwd())
        #find all files in directory                                                                                                                                                  
        print('Training on')
        path = os.getcwd()
    train_file_names = sorted([f for f in glob.glob(path + "/train/*_500mb.nc", recursive=True)])
    for f in train_file_names:
        print(f)

    print('Validating on')
    validate_file_names = sorted([f for f in glob.glob(path + "/validate/*_500mb.nc", recursive=True)])
    for f in validate_file_names:
        print(f)
    
    print('Testing on')
    test_file_names = sorted([f for f in glob.glob(path + "/test/*_500mb.nc", recursive=True)])
    for f in test_file_names:
         print(f)
    
    All_file_names =train_file_names + validate_file_names +test_file_names 
    
    rang = 861 #number of lat/lon points
    latlonfolder = '/glade/scratch/wchapman/AnEnCNN_good/Data/PNWpoints/'
    [latsDO,lonsDO,latind, lonind] = utilsProbSS.get_latlon_ind(latlonfolder)
    latsDO.shape
    latind = np.array(latind[:rang])
    lonind = np.array(lonind[:rang])
    latsDO = np.array(latsDO[:rang])
    lonsDO = np.array(lonsDO[:rang])

    norm_dict = utilsProbSS.get_image_normalization_params(train_file_names,latind,lonind)
    sys.stdout.flush()
    norm_dict_targ = utilsProbSS.get_image_normalization_params_targ(train_file_names,latind,lonind)
    # sys.stdout.flush()
    num_samps_train = utilsProb.count_samps(train_file_names)
    num_samps_val = utilsProb.count_samps(validate_file_names)
    num_samps_test = utilsProb.count_samps(test_file_names)

    print('number of training samples:',num_samps_train)
    # sys.stdout.flush()

    print('number of validation samples:',num_samps_val)
    # sys.stdout.flush()
    print('number of validation samples:',num_samps_test)
    num_samps_tot = num_samps_train+num_samps_val+num_samps_test
        
    ense = 60
    numbins = 15
    
    
    
    allinds = np.arange(len(All_file_names))
    avgvar_mA = np.zeros([len(All_file_names)-1,numbins])
    msebin_mA = np.zeros([len(All_file_names)-1,numbins])
    avgvar_sA = np.zeros([len(All_file_names)-1,numbins])
    msebin_sA = np.zeros([len(All_file_names)-1,numbins])

    mAl =np.array([])
    sAl =np.array([])
    yAl =np.array([])
    sssAl =np.empty([1,60])
    
    for ddfa, bb in enumerate(range(0,len(All_file_names)-1)):
        allinds = np.arange(len(All_file_names))
        test_fil_name = [All_file_names[allinds[bb+1]]]
        val_fil_name = [All_file_names[allinds[bb]]]

        rest = np.delete(allinds,[bb,bb+1])
        train_fil_name = np.array(All_file_names)[rest].tolist()
    
        print('#################################################')
        print('testing:',test_fil_name)
        print('validating:',val_fil_name)
        print('#################################################')
    
        num_samps_train = utilsProb.count_samps(train_fil_name)
        num_samps_val = utilsProb.count_samps(val_fil_name)

        print('...gathering data...')
        aa = utilsProbSS.deep_learning_generator_ss_mv(train_fil_name, num_samps_train*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
        adf = next(aa)
        x = adf[0]
        y = adf[1]
    
        ######## load testing ##############################################
        xpred = utilsProbSS.read_image_file(test_fil_name[0],latind,lonind)
        x_tst = np.reshape(xpred['predictor_matrix'],[xpred['predictor_matrix'].shape[0]*xpred['predictor_matrix'].shape[1],xpred['predictor_matrix'].shape[2]])
        y_tst = np.reshape(xpred['target_matrix'],[xpred['target_matrix'].shape[0]*xpred['target_matrix'].shape[1]])
        x_tst = utilsProbSS.normalize_images(x_tst,xpred['predictor_names'],norm_dict)[0]
        y_tst = utilsProbSS.normalize_images_targ(y_tst,xpred['target_name'],norm_dict_targ)[0]
        y_tst = np.expand_dims(y_tst,axis=1)

            ######## load testing ##############################################
            
            
        #remove x and y where x ==0 
        rmind = np.where(utilsProbSS.denormalize_images_targ(x[:,0],'IVT',norm_dict)==0)
        print('before shape:',y.shape)
        print('deleting:',rmind[0].shape,'indices')
        x = np.delete(x,rmind[0],0)
        y = np.delete(y,rmind[0],0)
        print('after shape:',y.shape)
    
        rmind = np.where(utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)==0)
        print('before shape test:',y_tst.shape)
        print('deleting test:',rmind[0].shape,'indices')
        x_tst = np.delete(x_tst,rmind[0],0)
        y_tst = np.delete(y_tst,rmind[0],0)
        print('after shape tst:',y_tst.shape)

        print('...Encoding Stations...')

        SUMID = np.unique(x[:,6]+x[:,7])
        #station ID integers 
        stID = np.zeros([x.shape[0],1])
        for jj,un in enumerate(SUMID):
            mats = np.where(x[:,6]+x[:,7]==un)
            stID[mats,:] = int(jj)
        stID=stID.astype(int)

        #station ID integers 
        stID_tst = np.zeros([x_tst.shape[0],1])
        for jj,un in enumerate(SUMID):
            mats = np.where(np.around(10000*np.round((x_tst[:,6]+x_tst[:,7]),4)).astype(int)==np.around(10000*np.round(un,4)).astype(int))[0]
            stID_tst[mats,:] = int(jj)
        stID_tst=stID_tst.astype(int)
        print('...done...')
        x=x[:,:6]
        x_tst=x_tst[:,:6]
    
        ### Model Build #### 
    
        in_shape = x.shape[1]
        print('In shape: ',in_shape)
        out_shape = 1
        print('Out shape: ',out_shape)
    
        max_id = np.max(stID)
        model = build_emb_model(in_shape,2,[30,40],2,max_id,compile=True)
        model.summary()
        valyr= val_fil_name[0].split('_500mb')[0]
        valyr =valyr.split('_')[2]
    
        tstyr= test_fil_name[0].split('_500mb')[0]
        tstyr =tstyr.split('_')[2]
    
        newdir = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/' +fcast+'/year_'+tstyr
    
        Wsave_name = newdir+'/cpf_CRPS_val_'+ valyr+'_test_'+tstyr+'.ckpt'
    
        print("... loading....",Wsave_name)
    
        ### CHANGE THIS FOR PRODUCTION RUNS ###########
        model.load_weights(Wsave_name)
        ### CHANGE THIS FOR PRODUCTION RUNS ###########
    
        #make model prediction
        yhat = model([x_tst,stID_tst])    
        m = yhat[:,0]
        m = (utilsProbSS.denormalize_images_targ(m,'IVT',norm_dict))
        s = np.abs(yhat[:,1]*norm_dict['IVT'][1])   
        WWRF = utilsProbSS.denormalize_images_targ(x_tst[:,0],'IVT',norm_dict)
        y_tst = (utilsProbSS.denormalize_images_targ(y_tst,'IVTm',norm_dict_targ))
    
        #form ensembles 
        m_All = np.zeros(len(m))
        sss_All = np.zeros([len(m),ense])
        s_All = np.zeros(len(m))
        for ii in range(len(m)):
            sss = np.random.normal(m[ii],s[ii],ense)
            sln=np.std(sss)
            mln=np.mean(sss)
            [mln,sln]=lognstat(np.mean(sss),np.std(sss))
            s_All[ii]=np.sqrt(sln)
            m_All[ii]=mln
            sss_All[ii,:] =np.exp(sss) 
    
    
        m = m_All
        m[np.isnan(m)]=0
        s=s_All
        s[np.isnan(m)]=0
    
        y_tst = np.exp(y_tst)
        WWRF = np.exp(WWRF)
        y_tst = y_tst[s<400]
        WWRF = WWRF[s<400]
        m = m[s<400]
        sss_All=sss_All[s<400,:]
        s = s[s<400]
        distPP = s
    
        mAl = np.append(mAl,np.ndarray.flatten(m))
        yAl = np.append(yAl,np.ndarray.flatten(y_tst))
        sAl = np.append(sAl,np.ndarray.flatten(s))
    
    
        if ddfa == 0:
            sssAl = sss_All
        else: 
            sssAl = np.concatenate([sssAl,sss_All],axis=0)
        
        print('...binned spread skill...')
        [avgvar_m,msebin_m,avgvar_s,msebin_s]=spreadskill(m,y_tst,distPP,numbins)
    
        avgvar_mA[bb,:] = np.squeeze(avgvar_m)
        msebin_mA[bb,:] = np.squeeze(msebin_m)
        avgvar_sA[bb,:] = np.squeeze(avgvar_s)
        msebin_sA[bb,:] = np.squeeze(msebin_s)
    
        plt.figure(figsize=[15,10])  # inches
        plt.errorbar(avgvar_m, (msebin_m), xerr=avgvar_s, yerr=msebin_s, uplims=True, lolims=True,color='r',linewidth=2)
        plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
        plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

        plt.tick_params(axis='x', labelsize=15)
        plt.tick_params(axis='y', labelsize=15)
        plt.title('Spread Skill Plot',fontsize=25)

        plt.plot([0,180],[0,180],'k--')
        plt.show()
    
        print(rmse(np.expand_dims(m,axis=1),y_tst))
        print(rmse(np.expand_dims(WWRF,axis=1),y_tst))
        print(crmse(np.expand_dims(m,axis=1),y_tst))
        print(crmse(np.expand_dims(WWRF,axis=1),y_tst))
        print(bias(np.expand_dims(m,axis=1),y_tst))
        print(bias(np.expand_dims(WWRF,axis=1),y_tst))
        if ddfa ==1:
            break
    
    print('banana')
    distPPT = (np.squeeze(sAl))
    print('...binned spread skill...')
    [avgvar_mT,msebin_mT,avgvar_sT,msebin_sT]=spreadskill(mAl,yAl,distPPT,numbins)
    
    print('saving:','/glade/scratch/wchapman/Reforecast/models/NN_CRPS/'+fcast+'/Spread_Skill_CRPS.npz')
    np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/'+fcast+'/Spread_Skill_CRPS.npz',mAl=mAl,yAl=yAl,distPPT=distPPT,
                    numbins=numbins,avgvar_mA=avgvar_mA,msebin_mA=msebin_mA,avgvar_sA=avgvar_sA,msebin_sA=msebin_sA)

    crps_ense = ps.crps_ensemble(np.squeeze(yAl[yAl>250]),sssAl[np.squeeze([yAl>250][0][:]),:])
    np.savez_compressed('/glade/scratch/wchapman/Reforecast/models/NN_CRPS/'+fcast+'/twCRPS_CRPS.npz',yAl=yAl,sssAl=sssAl,crps_ense=crps_ense)
    
    
    
    plt.figure(figsize=[15,10])  # inches
    mymap = cm.RdBu
    min, max = (1985, 2018)
    step = 1
    # to provide my colorbar info, then clearing the figure
    Z = [[0,0],[0,0]]
    levels = range(min,max+step,step)
    CS3 = plt.contourf(Z, levels, cmap=mymap)
    plt.clf()


    evenly_spaced_interval = np.linspace(0, 1, len(All_file_names)-1)
    colors = [cm.RdBu(x) for x in evenly_spaced_interval]

    # Plotting what I actually want
    Z=np.arange(1987,2017,1).tolist()
    count=0
    for ad,bd,cd,dd,ed in zip(avgvar_mA,msebin_mA,avgvar_sA,msebin_sA,Z):
            # setting rgb color based on z normalized to my range
        plt.errorbar(ad, bd, xerr=3*cd, yerr=3*dd, uplims=True, lolims=True,linewidth=2,color=colors[count],alpha=0.7)
    
        count+=1
    
    plt.errorbar(avgvar_mT, msebin_mT, xerr=3*avgvar_sT, yerr=3*msebin_sT, uplims=True, lolims=True,linewidth=4,color='k',alpha=1,label='Full Dataset')
    plt.legend(fontsize=20)
    plt.plot([0,200],[0,200],linestyle='--',linewidth=3,color=[0.5,0.5,0.5])

    plt.ylabel('Standard Error of the Mean $kg \:  m^{-1} \: s^{-1}$',fontsize=25)
    plt.xlabel('Binned Spread $kg \:  m^{-1} \: s^{-1}$',fontsize=25)

    plt.tick_params(axis='x', labelsize=20)
    plt.tick_params(axis='y', labelsize=20)
    plt.title('Boost Spread Skill Plot',fontsize=25)
    cb = plt.colorbar(CS3) # using the colorbar info I got from contourf
    cb.ax.tick_params(labelsize=20) 
    plt.xlim([0,180])
    plt.ylim([0,180])
    fname = '/glade/scratch/wchapman/Reforecast/models/NN_CRPS/'+fcast+'/Spread_Skill_CRPS.png'
    plt.savefig(fname, dpi=200, facecolor='w', edgecolor='w',
    orientation='portrait', papertype=None, format=None,
    transparent=False, bbox_inches="tight", pad_inches=0.1)
    plt.show()
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
    print('#####################################################################')
# Out:
# WARNING: GPU device not found.
# 1
# /glade/scratch/wchapman/Reforecast/F000
# Training on
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc
# Validating on
# /glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc
# Testing on
# /glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
#
#
# Mean and standard deviation for "IVT" = 4.7217, 0.9856
# Mean and standard deviation for "p_sfc" = 966.9993, 71.1576
# Mean and standard deviation for "u_tr_p" = 13.9722, 12.1949
# Mean and standard deviation for "v_tr_p" = 1.4144, 14.8680
# Mean and standard deviation for "Z_p" = 5552.1039, 143.8879
# Mean and standard deviation for "IWV" = 12.4031, 6.2757
# Mean and standard deviation for "lat" = 45.0000, 3.0277
# Mean and standard deviation for "lon" = -127.5000, 7.3951
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
#
#
# Mean and standard deviation for "IVTm" = 4.6846, 0.9775
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc"...
# number of training samples: 3880
# number of validation samples: 121
# number of validation samples: 121
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# before shape: (3340680, 1)
# deleting: (0,) indices
# after shape: (3340680, 1)
# before shape test: (104181, 1)
# deleting test: (0,) indices
# after shape tst: (104181, 1)
# ...Encoding Stations...
# ...done...
# In shape:  6
# Out shape:  1
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 2)         1722        input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2)            0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8)            0           input_1[0][0]
#                                                                  flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           270         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 40)           1240        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            82          dense_1[0][0]
# ==================================================================================================
# Total params: 3,314
# Trainable params: 3,314
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ... loading.... /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F000/year_1986/cpf_CRPS_val_1985_test_1986.ckpt
# ...binned spread skill...
# 47.08298038924819
# 48.90957391366401
# 47.03440617724539
# 48.881388996400965
# 2.1381482381330272
# 1.6601898080332091
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Reforecast/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc"...
# before shape: (3339819, 1)
# deleting: (0,) indices
# after shape: (3339819, 1)
# before shape test: (105042, 1)
# deleting test: (0,) indices
# after shape tst: (105042, 1)
# ...Encoding Stations...
# ...done...
# In shape:  6
# Out shape:  1
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 2)         1722        input_4[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2)            0           embedding_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8)            0           input_3[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           270         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 40)           1240        dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            82          dense_4[0][0]
# ==================================================================================================
# Total params: 3,314
# Trainable params: 3,314
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ... loading.... /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F000/year_1987/cpf_CRPS_val_1986_test_1987.ckpt
# ...binned spread skill...
# 46.28300076371699
# 46.4674867027245
# 46.11252783481069
# 46.413275599078055
# 3.9687449373871857
# 2.243918142871479
# banana
# ...binned spread skill...
# saving: /glade/scratch/wchapman/Reforecast/models/NN_CRPS/F000/Spread_Skill_CRPS.npz
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# #####################################################################
# 2
# /glade/scratch/wchapman/Reforecast/F000
# Training on
# /glade/scratch/wchapman/Reforecast/F006
# Training on
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc
# Validating on
# /glade/scratch/wchapman/Reforecast/F006/validate/F006_WY_2017_500mb.nc
# Testing on
# /glade/scratch/wchapman/Reforecast/F006/test/F006_WY_2018_500mb.nc
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc"...
#
#
# Mean and standard deviation for "IVT" = 4.7540, 0.9711
# Mean and standard deviation for "p_sfc" = 967.2730, 71.2149
# Mean and standard deviation for "u_tr_p" = 13.5922, 12.3055
# Mean and standard deviation for "v_tr_p" = 1.4922, 14.9247
# Mean and standard deviation for "Z_p" = 5551.2435, 146.5055
# Mean and standard deviation for "IWV" = 12.3230, 6.4324
# Mean and standard deviation for "lat" = 45.0000, 3.0277
# Mean and standard deviation for "lon" = -127.5000, 7.3951
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc"...
#
#
# Mean and standard deviation for "IVTm" = 4.6602, 0.9857
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc"...
# /glade/work/wchapman/AnEn/CNN/Reforecast/utilsProb.py:216: RuntimeWarning: invalid value encountered in log
#   post_matrix = numpy.log(post_matrix)
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/validate/F006_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/test/F006_WY_2018_500mb.nc"...
# number of training samples: 3880
# number of validation samples: 121
# number of validation samples: 121
# #################################################
# testing: ['/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc']
# validating: ['/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc']
# #################################################
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/validate/F006_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/test/F006_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc"...
# ...gathering data...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/test/F006_WY_2018_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/validate/F006_WY_2017_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc"...
# Reading data from: "/glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc"...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8d4e3ee102df> in <module>
#     401         print('...gathering data...')
#     402         aa = utilsProbSS.deep_learning_generator_ss_mv(train_fil_name, num_samps_train*len(latind),norm_dict,norm_dict_targ,targ_LATinds=latind,targ_LONinds=lonind)
# --> 403         adf = next(aa)
#     404         x = adf[0]
#     405         y = adf[1]
#
# /glade/work/wchapman/AnEn/CNN/Reforecast/utilsProbSS.py in deep_learning_generator_ss_mv(netcdf_file_names, num_examples_per_batch, normalization_dict, normalization_dict_targ, targ_LATinds, targ_LONinds)
#    1815                 this_image_dict = read_image_file(netcdf_file_names[file_index])
#    1816             else:
# -> 1817                 this_image_dict = read_image_file(netcdf_file_names[file_index],targ_LATinds,targ_LONinds)
#    1818
#    1819             predictor_names = this_image_dict[PREDICTOR_NAMES_KEY]
#
# /glade/work/wchapman/AnEn/CNN/Reforecast/utilsProbSS.py in read_image_file(netcdf_file_name, targ_LATinds, targ_LONinds)
#     167     for this_predictor_name in NETCDF_PREDICTOR_NAMES:
#     168         this_predictor_matrix = numpy.array(
# --> 169             dataset_object.variables[this_predictor_name][:], dtype=float
#     170         )
#     171
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# /glade/work/wchapman/miniconda3/envs/tfp/lib/python3.6/site-packages/netCDF4/utils.py in _StartCountStride(elem, shape, dimensions, grp, datashape, put, use_get_vars)
#     382     sdim.append(max(nDims, 1))
#     383     start = np.empty(sdim, dtype=int)
# --> 384     count = np.empty(sdim, dtype=int)
#     385     stride = np.empty(sdim, dtype=int)
#     386     indices = np.empty(sdim, dtype=object)
#
# KeyboardInterrupt:
