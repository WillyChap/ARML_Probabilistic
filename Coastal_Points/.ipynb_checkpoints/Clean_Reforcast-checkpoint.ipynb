# %% [markdown]
# # Purpose
# Clean reforecast

# %%
import xarray as xr
import glob
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# /glade/work/dgagne/ncar_python_tf/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
path ='/glade/scratch/wchapman/Reforecast/F006'

#find all files in directory                                                                                                                                                  
print('Training on')
train_file_names = sorted([f for f in glob.glob(path + "/train/*_500mb.nc", recursive=True)])
for f in train_file_names:
    print(f)

print('Validating on')
validate_file_names = sorted([f for f in glob.glob(path + "/validate/*_500mb.nc", recursive=True)])
for f in validate_file_names:
    print(f)
    
print('Testing on')
test_file_names = sorted([f for f in glob.glob(path + "/test/*_500mb.nc", recursive=True)])
for f in test_file_names:
    print(f)
    
All_file_names =train_file_names + validate_file_names +test_file_names
# Out:
# Training on
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1985_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1986_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1987_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1988_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1989_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1990_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1991_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1992_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1993_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1994_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1995_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1996_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1997_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1998_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_1999_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2000_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2001_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2002_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2003_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2004_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2005_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2006_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2007_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2008_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2009_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2010_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2011_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2012_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2013_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2014_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2015_500mb.nc
# /glade/scratch/wchapman/Reforecast/F006/train/F006_WY_2016_500mb.nc
# Validating on
# /glade/scratch/wchapman/Reforecast/F006/validate/F006_WY_2017_500mb.nc
# Testing on
# /glade/scratch/wchapman/Reforecast/F006/test/F006_WY_2018_500mb.nc

# %%
# fix: 072, 
All_file_names = ['/glade/scratch/wchapman/Reforecast/F072/train/F072_WY_2005_500mb.nc']

# %%
np.max(IVT)
# Out:
# 1516.0165

# %%
print(np.sum(np.isnan(DAR)).sum().sum().sum())
# Out:
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0

# %%
DAR['IVT'].shape
# Out:
# (121, 71, 57)

# %%
fcast = ['F'+f'{xx:03}' for xx in np.arange(0,126,6)]
# fcast = ['F060','F072']

checkvars =['IVT','T_p','Z_p','q_p','u_tr_p','v_tr_p']

for beans in fcast:
    path ='/glade/scratch/wchapman/Reforecast/'+beans

    #find all files in directory                                                                                                                                                  
    print('Training on')
    train_file_names = sorted([f for f in glob.glob(path + "/train/*_500mb.nc", recursive=True)])
    for f in train_file_names:
        print(f)

    print('Validating on')
    validate_file_names = sorted([f for f in glob.glob(path + "/validate/*_500mb.nc", recursive=True)])
    for f in validate_file_names:
        print(f)
    
    print('Testing on')
    test_file_names = sorted([f for f in glob.glob(path + "/test/*_500mb.nc", recursive=True)])
    for f in test_file_names:
        print(f)
    
    All_file_names =train_file_names + validate_file_names +test_file_names 


    

    for f in All_file_names:
        DAR =xr.open_dataset(f)
        print(np.sum(np.isnan(DAR)))
        for var in checkvars:
            print(f)
            IVT = DAR[var].data
#             print('SUM',np.sum(np.isnan(IVT)))
#             print('max:',np.max(IVT))
#             print('Im diving in !!!!! and I am fixing:',var)
            if np.sum(np.isnan(IVT)) > 0:
                print('in:', f)
                wherebad =np.where(np.isnan(IVT))
                print('Fixing here:',np.unique(wherebad[0]))
                IVT = DAR[var].data
                for ii in np.unique(wherebad[0]):
                    print('###################')
                    print('IM IN HERE!!!!! and I am fixing:',var)
                    print('###################')
                    print('HERE IS THE SUM BEFORE FIX: ',np.sum(np.isnan(IVT)))
                    inds = np.arange(0,IVT.shape[0])
                    inds_ii = np.where(wherebad[0]==ii)
                    avginds = np.delete(inds,np.unique(wherebad[0][inds_ii]))
                    IVT[ii,:,:] = np.mean(IVT[avginds.astype(int),:,:],axis=0) 
                    print('HERE IS THE SUM AFTER FIX: ',np.sum(np.isnan(IVT)))
                    print('replacing:',var)
                    DAR[var].data = IVT
            print('###################')
            print(np.sum(np.isnan(DAR)))
            print('###################')
        DAR.to_netcdf(f[:-3]+'_Clean.nc')
# Out:
# Training on
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1993_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1994_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1995_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1996_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1997_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1998_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1999_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2000_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2001_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2002_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2003_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2004_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2005_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2006_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2007_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2008_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2009_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2010_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2011_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2012_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2013_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2014_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2015_500mb.nc
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_2016_500mb.nc
# Validating on
# /glade/scratch/wchapman/Reforecast/F000/validate/F000_WY_2017_500mb.nc
# Testing on
# /glade/scratch/wchapman/Reforecast/F000/test/F000_WY_2018_500mb.nc
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1985_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1986_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1987_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1988_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1989_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F000/train/F000_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# ...
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1990_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1991_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################
# /glade/scratch/wchapman/Reforecast/F042/train/F042_WY_1992_500mb.nc
# ###################
# <xarray.Dataset>
# Dimensions:     ()
# Data variables:
#     pressure    int64 0
#     DateTime    int64 0
#     IVT         int64 0
#     IVTU        int64 0
#     IVTV        int64 0
#     IVTm        int64 0
#     IWV         int64 0
#     IWVm        int64 0
#     T_2m        int64 0
#     T_p         int64 0
#     Td_2m       int64 0
#     Z_p         int64 0
#     Z_sfc       int64 0
#     day         int64 0
#     hour        int64 0
#     minute      int64 0
#     month       int64 0
#     p_sfc       int64 0
#     precip      int64 0
#     precip_bkt  int64 0
#     q_2m        int64 0
#     q_p         int64 0
#     rh_2m       int64 0
#     uIVTm       int64 0
#     u_10m_tr    int64 0
#     u_tr_p      int64 0
#     v_10m_tr    int64 0
#     v_tr_p      int64 0
#     wd_10m      int64 0
#     ws_10m      int64 0
#     year        int64 0
#     vIVTm       int64 0
# ###################

# %%
DAR = xr.open_dataset('/glade/scratch/wchapman/Reforecast/F072/train/F072_WY_2005_500mb.nc')

# %%
Z_p = DAR['Z_p'].data

# %%
np.where(Z_p==np.nan)
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
np.where(np.isnan(Z_p))
# Out:
# (array([59, 59, 59, ..., 59, 59, 59]),
#  array([ 0,  0,  0, ..., 70, 70, 70]),
#  array([ 0,  1,  2, ..., 54, 55, 56]))

# %%
np.where(DAR[var]==np.nan)
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
plt.pcolor(Z_p[0,:,:])

# %%
plt.pcolor(np.mean(IVT[avginds.astype(int),:,:],axis=0))

# %%
IVT[ii,:,:]
plt.pcolor(IVT[ii,:,:])

# %%
wherebad =np.where(np.isnan(IVT))

# %%
wherebad
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
IVT[ii,:,:]
# Out:
# <xarray.DataArray 'v_tr_p' (lat: 71, lon: 57)>
# array([[-1.486704, -1.417155, -1.337598, ...,  1.865517,  1.932728,  2.069659],
#        [-1.508944, -1.540774, -1.490321, ...,  1.746257,  2.00103 ,  2.051205],
#        [-1.526135, -1.48501 , -1.57135 , ...,  1.750852,  1.910748,  2.038399],
#        ...,
#        [ 3.471069,  3.518579,  3.567859, ..., -1.396613, -1.72094 , -2.027366],
#        [ 3.912405,  3.828816,  3.770432, ..., -1.454029, -1.847235, -2.066664],
#        [ 4.534401,  4.420636,  4.196168, ..., -1.195693, -1.64249 , -1.899084]],
#       dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2005-12-20
#   * lon      (lon) float32 -150.0 -149.375 -148.75 ... -116.25 -115.625 -115.0
#   * lat      (lat) float32 25.0 25.5 26.0 26.5 27.0 ... 58.0 58.5 59.0 59.5 60.0
# Attributes:
#     standard_name:  northward_wind
#     long_name:      v-Component of Wind (Earth)
#     units:          m s-1
#     cell_methods:   pressure: mean

# %%
np.sum(np.isnan(DAR['IVT']))
# Out:
# <xarray.DataArray 'IVT' ()>
# array(0)

# %%
f[:-3]+'_Clean.nc'
# Out:
# '/glade/scratch/wchapman/Reforecast/F072/train/F072_WY_2005_500mb_Clean_Clean.nc'
